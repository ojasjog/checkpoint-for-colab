# %% [markdown]
# <a href="https://colab.research.google.com/github/ojasjog/checkpoint-for-colab/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate rembg pillow \
            torch torchvision albumentations ultralytics
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (0.38.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.10.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: rembg in /usr/local/lib/python3.12/dist-packages (2.0.76)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (12.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.26.0+cu128)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.75)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers) (3.29.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (1.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.4.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.32.4)
# Requirement already satisfied: safetensors>=0.8.0-rc.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from rembg) (4.26.0)
# Requirement already satisfied: pooch<2.0.0,>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from rembg) (1.9.0)
# Requirement already satisfied: pymatting<2.0.0,>=1.1.14 in /usr/local/lib/python3.12/dist-packages (from rembg) (1.1.15)
# Requirement already satisfied: scikit-image<0.27.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from rembg) (0.26.0)
# Requirement already satisfied: scipy<2.0.0,>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from rembg) (1.16.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.16)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.5.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg) (2026.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch<2.0.0,>=1.8.2->rembg) (4.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from pymatting<2.0.0,>=1.1.14->rembg) (0.65.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg) (0.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->pymatting<2.0.0,>=1.1.14->rembg) (0.47.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
# !pip install "rembg[gpu]"
# !pip install "rembg[cpu]"
# Out:
# Requirement already satisfied: rembg[gpu] in /usr/local/lib/python3.12/dist-packages (2.0.76)
# Requirement already satisfied: jsonschema<5.0.0,>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (4.26.0)
# Requirement already satisfied: numpy<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (2.4.6)
# Requirement already satisfied: onnxruntime-gpu<2.0.0,>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (1.27.0)
# Requirement already satisfied: pillow<13.0.0,>=12.1.0 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (12.2.0)
# Requirement already satisfied: pooch<2.0.0,>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (1.9.0)
# Requirement already satisfied: pymatting<2.0.0,>=1.1.14 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (1.1.15)
# Requirement already satisfied: scikit-image<0.27.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (0.26.0)
# Requirement already satisfied: scipy<2.0.0,>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (1.16.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from rembg[gpu]) (4.67.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[gpu]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[gpu]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[gpu]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[gpu]) (2026.5.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu<2.0.0,>=1.23.2->rembg[gpu]) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu<2.0.0,>=1.23.2->rembg[gpu]) (26.2)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu<2.0.0,>=1.23.2->rembg[gpu]) (5.29.6)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch<2.0.0,>=1.8.2->rembg[gpu]) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch<2.0.0,>=1.8.2->rembg[gpu]) (2.32.4)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from pymatting<2.0.0,>=1.1.14->rembg[gpu]) (0.65.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[gpu]) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[gpu]) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[gpu]) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[gpu]) (0.5)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->pymatting<2.0.0,>=1.1.14->rembg[gpu]) (0.47.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema<5.0.0,>=4.25.1->rembg[gpu]) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[gpu]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[gpu]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[gpu]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[gpu]) (2026.5.20)
# Requirement already satisfied: rembg[cpu] in /usr/local/lib/python3.12/dist-packages (2.0.76)
# Requirement already satisfied: jsonschema<5.0.0,>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (4.26.0)
# Requirement already satisfied: numpy<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (2.4.6)
# Collecting onnxruntime<2.0.0,>=1.23.2 (from rembg[cpu])
#   Downloading onnxruntime-1.27.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pillow<13.0.0,>=12.1.0 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (12.2.0)
# Requirement already satisfied: pooch<2.0.0,>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (1.9.0)
# Requirement already satisfied: pymatting<2.0.0,>=1.1.14 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (1.1.15)
# Requirement already satisfied: scikit-image<0.27.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (0.26.0)
# Requirement already satisfied: scipy<2.0.0,>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (1.16.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from rembg[cpu]) (4.67.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[cpu]) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[cpu]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[cpu]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.25.1->rembg[cpu]) (2026.5.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.23.2->rembg[cpu]) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.23.2->rembg[cpu]) (26.2)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2.0.0,>=1.23.2->rembg[cpu]) (5.29.6)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch<2.0.0,>=1.8.2->rembg[cpu]) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch<2.0.0,>=1.8.2->rembg[cpu]) (2.32.4)
# Requirement already satisfied: numba>=0.60.0 in /usr/local/lib/python3.12/dist-packages (from pymatting<2.0.0,>=1.1.14->rembg[cpu]) (0.65.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[cpu]) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[cpu]) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[cpu]) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<0.27.0,>=0.26.0->rembg[cpu]) (0.5)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.60.0->pymatting<2.0.0,>=1.1.14->rembg[cpu]) (0.47.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema<5.0.0,>=4.25.1->rembg[cpu]) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[cpu]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[cpu]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[cpu]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch<2.0.0,>=1.8.2->rembg[cpu]) (2026.5.20)
# Downloading onnxruntime-1.27.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 92.4 MB/s eta 0:00:00
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.27.0

# %%
# %%writefile generate_assets.py
"""
Photorealistic Animal Dataset Generator - Production Configuration
==================================================================
Optimized with Background Caching, Alpha Matting, and Kaggle-Ready Augmentations.
"""

import random
import warnings
from pathlib import Path

import numpy as np
import torch
import albumentations as A
from PIL import Image
from diffusers import (
    AutoencoderKL,
    StableDiffusionImg2ImgPipeline,
    StableDiffusionPipeline,
    DPMSolverMultistepScheduler,
)
from rembg import new_session, remove as rembg_remove

warnings.filterwarnings("ignore", category=FutureWarning)

# ─────────────────────────────── CONFIG ──────────────────────────────────────

MODEL_ID  = "SG161222/Realistic_Vision_V5.1_noVAE"
VAE_ID    = "stabilityai/sd-vae-ft-mse"

CLASSES = {0: "fox", 1: "leopard", 2: "sheep"}

ANIMAL_PROMPTS = {
    0: [
        "RAW photo of a red fox sitting on grass, Canon EOS R5, 85mm f/1.4, sharp focus, natural fur texture, bokeh background, 8k uhd, photorealistic, white background",
        "RAW photo of a red fox standing alert, looking forward, Fujifilm XT3, natural lighting, highly detailed fur, white background, photorealistic",
        "RAW photo of a red fox lying down, relaxed, DSLR, natural lighting, sharp fur detail, photorealistic, white background",
        "RAW photo of a red fox walking, side profile, 85mm lens, natural lighting, photorealistic, detailed fur texture, white background",
        "RAW close-up portrait of a red fox, 100mm macro, shallow depth of field, individual fur strands visible, photorealistic, white background",
        "RAW photo of a red fox crouching low to the ground, stalking pose, dynamic angle, highly detailed, photorealistic, white background",
        "RAW photo of a red fox mid-stride, running action pose, sharp focus, side view, natural muscle definition, photorealistic, white background",
        "RAW photo of a red fox looking over its shoulder, back profile, high-end photography, sharp details, photorealistic, white background",
        "RAW photo of a red fox curling up tightly, resting posture, compact silhouette, soft lighting, photorealistic, white background",
        "RAW photo of a red fox with its head tilted curiously, tight portrait shot, expressive eyes, sharp whiskers, photorealistic, white background",
        "RAW low-angle shot of a red fox standing proudly, looking upward, dramatic natural lighting, highly detailed, photorealistic, white background",
        "RAW photo of a red fox yawning, open mouth detail, visible teeth and tongue, macro lens, sharp focus, photorealistic, white background",
        "RAW photo of a red fox stretching its front legs forward, elongated body posture, full body view, photorealistic, white background",
        "RAW three-quarter portrait of an adult red fox, sharp eye contact, studio lighting style, flawless fur texture, photorealistic, white background",
        "RAW photo of a slender red fox stepping forward cautiously, front-facing action pose, highly detailed coat, photorealistic, white background",
    ],
    1: [
        "RAW photo of a leopard sitting, Canon EOS R5, 400mm telephoto, sharp spotted coat, natural lighting, 8k uhd, photorealistic, white background",
        "RAW photo of a leopard standing alert, Nikon D850, natural savanna light, detailed rosette pattern, photorealistic, white background",
        "RAW photo of a leopard walking, side profile, telephoto lens, motion-ready pose, photorealistic, detailed coat, white background",
        "RAW photo of a leopard lying down, relaxed, DSLR, dappled natural light, photorealistic fur detail, white background",
        "RAW close-up portrait of a leopard, 100mm lens, shallow DOF, eye detail, whisker texture, photorealistic, white background",
        "RAW photo of a leopard crouching, low angle, dramatic natural lighting, photorealistic, detailed spotted coat, white background",
        "RAW photo of a leopard pacing forward directly toward the camera, powerful front profile, fierce gaze, highly detailed, photorealistic, white background",
        "RAW photo of a leopard lying on its side, fully extended lazy posture, clear belly and spot patterns, sharp focus, photorealistic, white background",
        "RAW high-angle shot of a leopard looking up, unique spatial perspective, sharp feline features, photorealistic, white background",
        "RAW photo of a leopard snarling, aggressive facial expression, detailed teeth and jaw structure, macro zoom, photorealistic, white background",
        "RAW photo of a leopard in a tense, muscular pre-leap posture, coiled energy, detailed muscle definitions, photorealistic, white background",
        "RAW tight close-up of a leopard's face and shoulders, striking green eyes, crisp whisker pores, ultra-high texture, photorealistic, white background",
        "RAW photo of a leopard turning its head sharply to the right, dramatic side neck silhouette, clear rosette details, photorealistic, white background",
        "RAW photo of a leopard stretching its back, arched spine posture, full body profile, highly detailed coat, photorealistic, white background",
        "RAW macro portrait of an apex leopard, direct intense eye contact, detailed fur grain, professional wildlife photography, photorealistic, white background",
    ],
    2: [
        "RAW photo of a sheep standing, Canon EOS R5, natural daylight, individual wool fibers visible, 8k uhd, photorealistic, white background",
        "RAW photo of a sheep grazing, DSLR, warm golden hour light, photorealistic, detailed fleece texture, white background",
        "RAW close-up portrait of a sheep, 85mm lens, shallow DOF, photorealistic wool and eye detail, white background",
        "RAW photo of a sheep walking, side profile, natural lighting, photorealistic, detailed fleece, white background",
        "RAW photo of a sheep with its head turned completely to the side, crisp profile view, thick fleece texture, photorealistic, white background",
        "RAW front-facing portrait of a sheep looking directly ahead, symmetrical composition, detailed face and ears, photorealistic, white background",
        "RAW low-angle photo of a sheep standing on an incline, majestic posture, sharp focus on thick wool, photorealistic, white background",
        "RAW photo of a sheep chewing grass, candid expression, detailed jaw and fleece structure, highly realistic, white background",
        "RAW photo of a sheep lying down, resting posture, compact rounded fleece silhouette, soft natural lighting, photorealistic, white background",
        "RAW macro shot of a sheep's face, extreme detail on the snout, eyes, and curly wool head-cap, photorealistic, white background",
        "RAW photo of a sheep running, dynamic movement pose, side view, natural motion framing, photorealistic, white background",
        "RAW photo of a sheep tilting its head downward, curious posture, sharp focus on the texture of the coat, photorealistic, white background",
        "RAW three-quarter body shot of a mature sheep, heavy detailed fleece, professional farm wildlife shot, photorealistic, white background",
        "RAW photo of a sheep shaking its head, dynamic action blur minimization, crisp facial features, thick woolly body, photorealistic, white background",
        "RAW photo of a fluffy sheep stepping forward, front action view, detailed hooves and lower leg wool, photorealistic, white background",
    ],
}

ANIMAL_NEG_PROMPT = (
    "blurry, watermark, text, multiple animals, cartoon, anime, illustration, "
    "painting, render, CGI, 3d, plastic, smooth, overexposed, oversaturated, "
    "bad anatomy, extra limbs, deformed, disfigured, ugly, low quality, "
    "low resolution, grainy noise, jpeg artifacts, logo, signature, bad eyes, deformed iris"
)

BACKGROUND_PROMPTS = [
    "RAW photo of a sunny forest clearing, photorealistic landscape, empty environment, no animals, 8k uhd, natural lighting, Canon EOS R5",
    "RAW photo of a grassy meadow at golden hour, photorealistic field, empty, no animals, warm volumetric light, 8k uhd, Nikon D850",
    "RAW photo of a rocky hillside with sparse dry trees, photorealistic mountain terrain, no animals, natural bright lighting, 8k uhd",
    "RAW photo of a snowy woodland path, silent winter forest landscape, photorealistic, no animals, soft diffuse overcast light",
    "RAW photo of an autumn forest floor covered with vibrant fallen leaves, macro ground texture focus, photorealistic, no animals",
    "RAW photo of a riverbank with smooth pebbles and patches of wild grass, clear water edge, photorealistic, no animals, natural bright daylight",
    "RAW photo of a wide countryside field at dusk, rolling hills background, photorealistic, no animals, cinematic golden hour light",
    "RAW photo of a sunny open savanna, dry yellow grass plain, photorealistic landscape, no animals, 8k uhd, sharp deep horizon",
    "RAW photo of a dense jungle interior, tropical foliage, photorealistic moss and ferns, no animals, natural dappled light filtering through trees",
    "RAW photo of a dry scrubland desert, arid environment with low bushes, photorealistic, no animals, harsh clear natural lighting",
]

BACKGROUND_NEG_PROMPT = "people, humans, animals, birds, insects, text, watermark, cartoon, painting, render, CGI, 3d"

CANVAS_W, CANVAS_H = 640, 640
FG_SCALE_MIN, FG_SCALE_MAX = 0.25, 0.55
NUM_AUGMENTED_IMAGES = 1000  # Outputs 1000 per class
SEED = 42
OUTPUT_DIR = Path("combined_dataset")

BASE_SIZE        = (512, 512)
HIRES_SIZE       = (640, 640)  # Native match for YOLO grid dimension
HIRES_DENOISE    = 0.45
BASE_STEPS       = 18          # Super fast convergence with DPM++ Karras
HIRES_STEPS      = 12
CFG_SCALE        = 5.5
BG_CFG_SCALE     = 5.5

# ─────────────────────────────── SCHEDULER ───────────────────────────────────

def make_dpm_karras_scheduler(config) -> DPMSolverMultistepScheduler:
    return DPMSolverMultistepScheduler.from_config(
        config, algorithm_type="dpmsolver++", solver_type="midpoint", use_karras_sigmas=True
    )

# ─────────────────────────────── SD PIPELINES ────────────────────────────────

def _apply_memory_optimisations(pipe, device: str) -> None:
    if device == "cpu": return
    try:
        pipe.enable_xformers_memory_efficient_attention()
        return
    except Exception: pass
    if hasattr(torch.nn.functional, "scaled_dot_product_attention"):
        try:
            from diffusers.models.attention_processor import AttnProcessor2_0
            pipe.unet.set_attn_processor(AttnProcessor2_0())
            return
        except Exception: pass
    pipe.enable_sequential_cpu_offload()

def load_pipelines() -> tuple[StableDiffusionPipeline, StableDiffusionImg2ImgPipeline]:
    device = "cuda" if torch.cuda.is_available() else "cpu"
    dtype  = torch.float16 if device == "cuda" else torch.float32
    print(f"[SD] Loading {MODEL_ID} …")

    vae = AutoencoderKL.from_pretrained(VAE_ID, torch_dtype=dtype)
    txt2img = StableDiffusionPipeline.from_pretrained(MODEL_ID, vae=vae, torch_dtype=dtype, safety_checker=None).to(device)
    img2img = StableDiffusionImg2ImgPipeline.from_pretrained(
        MODEL_ID, vae=vae, text_encoder=txt2img.text_encoder, tokenizer=txt2img.tokenizer,
        unet=txt2img.unet, safety_checker=None, torch_dtype=dtype
    ).to(device)

    txt2img.scheduler = make_dpm_karras_scheduler(txt2img.scheduler.config)
    img2img.scheduler = make_dpm_karras_scheduler(img2img.scheduler.config)

    _apply_memory_optimisations(txt2img, device)
    _apply_memory_optimisations(img2img, device)
    return txt2img, img2img

# ─────────────────────────────── GENERATION ──────────────────────────────────

def _make_generator(pipe, seed: int) -> torch.Generator:
    return torch.Generator(device=pipe.device).manual_seed(seed)

def generate_image_hires(txt2img, img2img, prompt, negative_prompt, base_size, hires_size, base_steps, hires_steps, cfg_scale, seed) -> Image.Image:
    gen1 = _make_generator(txt2img, seed)
    base_img = txt2img(
        prompt=prompt, negative_prompt=negative_prompt, width=base_size[0], height=base_size[1],
        num_inference_steps=base_steps, guidance_scale=cfg_scale, generator=gen1
    ).images[0]

    upscaled_img = base_img.resize(hires_size, Image.LANCZOS)
    gen2 = _make_generator(img2img, seed + 1)
    final_img = img2img(
        prompt=prompt, negative_prompt=negative_prompt, image=upscaled_img, strength=HIRES_DENOISE,
        num_inference_steps=hires_steps, guidance_scale=cfg_scale, generator=gen2
    ).images[0]
    return final_img

# ─────────────────────────────── REMBG MATTING FIX ───────────────────────────

REMBG_SESSION = new_session("isnet-general-use")

def remove_background(img: Image.Image) -> Image.Image:
    # Alpha Matting isolates hair/fur outlines completely
    return rembg_remove(
        img, session=REMBG_SESSION, alpha_matting=True,
        alpha_matting_foreground_threshold=240,
        alpha_matting_background_threshold=10,
        alpha_matting_erode_size=10
    )

def crop_to_content(rgba: Image.Image) -> Image.Image:
    bbox = rgba.getbbox()
    return rgba.crop(bbox) if bbox else rgba

def resize_foreground(fg: Image.Image, canvas_w: int, canvas_h: int) -> Image.Image:
    scale    = random.uniform(FG_SCALE_MIN, FG_SCALE_MAX)
    target_w = int(canvas_w * scale)
    target_h = int(target_w * (fg.height / fg.width))
    return fg.resize((target_w, target_h), Image.LANCZOS)

# ─────────────────────────────── AUGMENTATION ────────────────────────────────

def build_fg_augmenter() -> A.Compose:
    # Hardened to mimic chaotic real-world Kaggle OpenImage distributions
    return A.Compose([
        A.HorizontalFlip(p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.35, contrast_limit=0.35, p=0.8),
        A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.6),
        A.CoarseDropout(max_holes=12, max_height=32, max_width=32, fill_value=0, p=0.4),
        A.MotionBlur(blur_limit=5, p=0.3),
        A.Rotate(limit=15, border_mode=0, p=0.5),
    ])

def augment_foreground(fg_rgba: Image.Image, augmenter: A.Compose, idx: int) -> Image.Image:
    rgb   = np.array(fg_rgba.convert("RGB"))
    alpha = np.array(fg_rgba.split()[-1])

    random.seed(SEED + idx)
    np.random.seed(SEED + idx)
    aug_rgb = augmenter(image=rgb)["image"]

    random.seed(SEED + idx)
    np.random.seed(SEED + idx)
    aug_alpha = augmenter(image=np.stack([alpha] * 3, axis=-1))["image"][:, :, 0]

    res = Image.fromarray(aug_rgb).convert("RGBA")
    r, g, b, _ = res.split()
    return Image.merge("RGBA", (r, g, b, Image.fromarray(aug_alpha)))

# ─────────────────────────────── COMPOSITE ───────────────────────────────────

def composite_and_label(bg: Image.Image, fg_rgba: Image.Image, canvas_w: int, canvas_h: int, idx: int, class_id: int) -> tuple:
    canvas = bg.copy().convert("RGB").resize((canvas_w, canvas_h), Image.LANCZOS)
    fg     = resize_foreground(fg_rgba, canvas_w, canvas_h)
    fg_w, fg_h = fg.size

    random.seed(SEED + idx * 13)
    x_offset = random.randint(0, max(canvas_w - fg_w, 0))
    y_offset  = random.randint(0, max(canvas_h - fg_h, 0))

    canvas.paste(fg, (x_offset, y_offset), mask=fg.split()[3])

    fg_alpha = np.array(fg.split()[3])
    rows = np.any(fg_alpha > 10, axis=1)
    cols = np.any(fg_alpha > 10, axis=0)

    if rows.any() and cols.any():
        r_min, r_max = np.where(rows)[0][[0, -1]]
        c_min, c_max = np.where(cols)[0][[0, -1]]
        abs_x1, abs_y1 = x_offset + c_min, y_offset + r_min
        abs_x2, abs_y2 = x_offset + c_max, y_offset + r_max
    else:
        abs_x1, abs_y1 = x_offset, y_offset
        abs_x2, abs_y2 = x_offset + fg_w, y_offset + fg_h

    cx = ((abs_x1 + abs_x2) / 2) / canvas_w
    cy = ((abs_y1 + abs_y2) / 2) / canvas_h
    bw = (abs_x2 - abs_x1) / canvas_w
    bh = (abs_y2 - abs_y1) / canvas_h

    return canvas, f"{class_id} {cx:.6f} {cy:.6f} {bw:.6f} {bh:.6f}"

def write_data_yaml(output_dir: Path, classes: dict) -> None:
    names_str = "[" + ", ".join(f"'{n}'" for n in classes.values()) + "]"
    (output_dir / "data.yaml").write_text(
        f"path: {output_dir.resolve()}\ntrain: images/train\nval: images/val\nnc: {len(classes)}\nnames: {names_str}\n"
    )

# ─────────────────────────────── MAIN EXECUTION ──────────────────────────────

def main() -> None:
    img_dir = OUTPUT_DIR / "images" / "train"
    lbl_dir = OUTPUT_DIR / "labels" / "train"
    img_dir.mkdir(parents=True, exist_ok=True)
    lbl_dir.mkdir(parents=True, exist_ok=True)

    txt2img, img2img = load_pipelines()
    augmenter = build_fg_augmenter()

    print(f"\n[1/3] Caching {len(BACKGROUND_PROMPTS)} Background Landscapes Exactly Once...")
    bg_list = []
    for bi, prompt in enumerate(BACKGROUND_PROMPTS):
        print(f"      Processing background layout [{bi+1}/{len(BACKGROUND_PROMPTS)}] ...")
        bg = generate_image_hires(
            txt2img, img2img, prompt=prompt, negative_prompt=BACKGROUND_NEG_PROMPT,
            base_size=(512, 512), hires_size=HIRES_SIZE, base_steps=BASE_STEPS,
            hires_steps=HIRES_STEPS, cfg_scale=BG_CFG_SCALE, seed=SEED + 500 + bi
        )
        bg_list.append(bg)

    for class_id, class_name in CLASSES.items():
        prompts = ANIMAL_PROMPTS[class_id]
        print(f"\n[2/3] Class {class_id} '{class_name}' — Extracting shapes via {len(prompts)} distinct foreground templates…")

        fg_list = []
        for fi, prompt in enumerate(prompts):
            print(f"      [{fi+1}/{len(prompts)}] Isolating foreground silhouette …")
            fg_raw = generate_image_hires(
                txt2img, img2img, prompt=prompt, negative_prompt=ANIMAL_NEG_PROMPT,
                base_size=BASE_SIZE, hires_size=HIRES_SIZE, base_steps=BASE_STEPS,
                hires_steps=HIRES_STEPS, cfg_scale=CFG_SCALE, seed=SEED + class_id * 100 + fi
            )
            fg_rgba = remove_background(fg_raw)
            fg_rgba = crop_to_content(fg_rgba)
            fg_list.append(fg_rgba)

        print(f"\n[3/3] Class {class_id} '{class_name}' — Compiling {NUM_AUGMENTED_IMAGES} domain-hardened training frames...")
        for i in range(NUM_AUGMENTED_IMAGES):
            fg_rgba = fg_list[i % len(fg_list)]
            bg      = bg_list[random.randint(0, len(bg_list) - 1)]

            aug_fg  = augment_foreground(fg_rgba, augmenter, idx=class_id * 10000 + i)
            composite, label = composite_and_label(bg, aug_fg, CANVAS_W, CANVAS_H, idx=class_id * 10000 + i, class_id=class_id)

            img_name = f"sample_{class_id}_{i:04d}.jpg"
            composite.save(img_dir / img_name, quality=95)
            (lbl_dir / f"sample_{class_id}_{i:04d}.txt").write_text(label + "\n")

            if (i + 1) % 250 == 0 or i == 0:
                print(f"      Assembled [{i+1}/{NUM_AUGMENTED_IMAGES}] → {img_name}")

    write_data_yaml(OUTPUT_DIR, CLASSES)
    print(f"\n✅ Asset script execution successfully finished.")

if __name__ == "__main__":
    main()
# Out:
# Overwriting generate_assets.py

# %%
# !python generate_assets.py
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/isnet-general-use.onnx' to file '/root/.u2net/isnet-general-use.onnx'.
# 100%|████████████████████████████████████████| 179M/179M [00:00<00:00, 892GB/s]
# [SD] Loading SG161222/Realistic_Vision_V5.1_noVAE …
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 547/547 [00:00<00:00, 2.57MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:04<00:00, 74.2MB/s]
# model_index.json: 100% 609/609 [00:00<00:00, 3.43MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 548/548 [00:00<00:00, 2.16kB/s]
# Downloading (incomplete total...):  17% 683M/3.93G [00:08<00:40, 79.6MB/s]
# Downloading (incomplete total...): 100% 3.93G/3.93G [00:43<00:00, 75.9MB/s]
# Fetching 10 files: 100% 10/10 [00:43<00:00,  4.37s/it]
# Download complete: 100% 3.93G/3.93G [00:43<00:00, 75.9MB/s]
# Download complete: 100% 3.93G/3.93G [00:43<00:00, 89.8MB/s]
#
# Loading pipeline components...:  20% 1/5 [00:16<01:06, 16.61s/it]
# Loading weights: 100% 196/196 [00:01<00:00, 101.02it/s]
#
# Loading pipeline components...: 100% 5/5 [00:19<00:00,  3.81s/it]
# Loading pipeline components...: 100% 5/5 [00:00<00:00, 1782.99it/s]
# /content/generate_assets.py:215: UserWarning: Argument(s) 'max_holes, max_height, max_width, fill_value' are not valid for transform CoarseDropout
#   A.CoarseDropout(max_holes=12, max_height=32, max_width=32, fill_value=0, p=0.4),
#
# [1/3] Caching 10 Background Landscapes Exactly Once...
#       Processing background layout [1/10] ...
# 100% 18/18 [00:03<00:00,  5.66it/s]
# 100% 5/5 [00:01<00:00,  4.84it/s]
#       Processing background layout [2/10] ...
# 100% 18/18 [00:02<00:00,  7.99it/s]
# 100% 5/5 [00:00<00:00,  5.10it/s]
#       Processing background layout [3/10] ...
# 100% 18/18 [00:02<00:00,  7.90it/s]
# 100% 5/5 [00:00<00:00,  5.03it/s]
#       Processing background layout [4/10] ...
# 100% 18/18 [00:02<00:00,  7.84it/s]
# 100% 5/5 [00:01<00:00,  4.99it/s]
#       Processing background layout [5/10] ...
# 100% 18/18 [00:02<00:00,  7.79it/s]
# 100% 5/5 [00:01<00:00,  4.96it/s]
#       Processing background layout [6/10] ...
# 100% 18/18 [00:02<00:00,  7.68it/s]
# 100% 5/5 [00:01<00:00,  4.88it/s]
#       Processing background layout [7/10] ...
# 100% 18/18 [00:02<00:00,  7.63it/s]
# 100% 5/5 [00:01<00:00,  4.84it/s]
#       Processing background layout [8/10] ...
# 100% 18/18 [00:02<00:00,  7.49it/s]
# 100% 5/5 [00:01<00:00,  4.79it/s]
#       Processing background layout [9/10] ...
# 100% 18/18 [00:02<00:00,  7.45it/s]
# 100% 5/5 [00:01<00:00,  4.72it/s]
#       Processing background layout [10/10] ...
# 100% 18/18 [00:02<00:00,  7.43it/s]
# 100% 5/5 [00:01<00:00,  4.73it/s]
#
# [2/3] Class 0 'fox' — Extracting shapes via 15 distinct foreground templates…
#       [1/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  7.40it/s]
# 100% 5/5 [00:01<00:00,  4.68it/s]
#       [2/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  7.11it/s]
# 100% 5/5 [00:01<00:00,  4.61it/s]
#       [3/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  7.02it/s]
# 100% 5/5 [00:01<00:00,  4.55it/s]
#       [4/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.95it/s]
# 100% 5/5 [00:01<00:00,  4.53it/s]
#       [5/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.87it/s]
# 100% 5/5 [00:01<00:00,  4.45it/s]
#       [6/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.69it/s]
# 100% 5/5 [00:01<00:00,  4.35it/s]
#       [7/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.60it/s]
# 100% 5/5 [00:01<00:00,  4.32it/s]
#       [8/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.46it/s]
# 100% 5/5 [00:01<00:00,  4.21it/s]
#       [9/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.34it/s]
# 100% 5/5 [00:01<00:00,  4.09it/s]
#       [10/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.16it/s]
# 100% 5/5 [00:01<00:00,  3.99it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#       [11/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.95it/s]
# 100% 5/5 [00:01<00:00,  3.83it/s]
#       [12/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.78it/s]
# 100% 5/5 [00:01<00:00,  3.72it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 1.000000e-04
# Try decreasing discard_threshold or start with a larger shift
#
#       [13/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.23it/s]
# 100% 5/5 [00:01<00:00,  4.02it/s]
#       [14/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.98it/s]
# 100% 5/5 [00:01<00:00,  3.85it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#       [15/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.77it/s]
# 100% 5/5 [00:01<00:00,  3.70it/s]
#
# [3/3] Class 0 'fox' — Compiling 1000 domain-hardened training frames...
#       Assembled [1/1000] → sample_0_0000.jpg
#       Assembled [250/1000] → sample_0_0249.jpg
#       Assembled [500/1000] → sample_0_0499.jpg
#       Assembled [750/1000] → sample_0_0749.jpg
#       Assembled [1000/1000] → sample_0_0999.jpg
#
# [2/3] Class 1 'leopard' — Extracting shapes via 15 distinct foreground templates…
#       [1/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.22it/s]
# 100% 5/5 [00:01<00:00,  3.98it/s]
#       [2/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.99it/s]
# 100% 5/5 [00:01<00:00,  3.79it/s]
#       [3/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.74it/s]
# 100% 5/5 [00:01<00:00,  3.63it/s]
#       [4/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.73it/s]
# 100% 5/5 [00:01<00:00,  3.75it/s]
#       [5/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.97it/s]
# 100% 5/5 [00:01<00:00,  3.93it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#       [6/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.46it/s]
# 100% 5/5 [00:01<00:00,  4.15it/s]
#       [7/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.23it/s]
# 100% 5/5 [00:01<00:00,  3.98it/s]
#       [8/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.98it/s]
# 100% 5/5 [00:01<00:00,  3.82it/s]
#       [9/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.70it/s]
# 100% 5/5 [00:01<00:00,  3.65it/s]
#       [10/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.73it/s]
# 100% 5/5 [00:01<00:00,  3.74it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#       [11/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.30it/s]
# 100% 5/5 [00:01<00:00,  4.11it/s]
#       [12/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.26it/s]
# 100% 5/5 [00:01<00:00,  4.04it/s]
#       [13/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.09it/s]
# 100% 5/5 [00:01<00:00,  3.91it/s]
#       [14/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.93it/s]
# 100% 5/5 [00:01<00:00,  3.81it/s]
#       [15/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.89it/s]
# 100% 5/5 [00:01<00:00,  3.81it/s]
#
# [3/3] Class 1 'leopard' — Compiling 1000 domain-hardened training frames...
#       Assembled [1/1000] → sample_1_0000.jpg
#       Assembled [250/1000] → sample_1_0249.jpg
#       Assembled [500/1000] → sample_1_0499.jpg
#       Assembled [750/1000] → sample_1_0749.jpg
#       Assembled [1000/1000] → sample_1_0999.jpg
#
# [2/3] Class 2 'sheep' — Extracting shapes via 15 distinct foreground templates…
#       [1/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.27it/s]
# 100% 5/5 [00:01<00:00,  4.02it/s]
#       [2/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.01it/s]
# 100% 5/5 [00:01<00:00,  3.90it/s]
#       [3/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.77it/s]
# 100% 5/5 [00:01<00:00,  3.65it/s]
#       [4/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.69it/s]
# 100% 5/5 [00:01<00:00,  3.71it/s]
#       [5/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.97it/s]
# 100% 5/5 [00:01<00:00,  3.92it/s]
#       [6/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.30it/s]
# 100% 5/5 [00:01<00:00,  4.09it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#       [7/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.27it/s]
# 100% 5/5 [00:01<00:00,  4.06it/s]
#       [8/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.03it/s]
# 100% 5/5 [00:01<00:00,  3.87it/s]
#       [9/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.83it/s]
# 100% 5/5 [00:01<00:00,  3.74it/s]
#       [10/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.73it/s]
# 100% 5/5 [00:01<00:00,  3.68it/s]
# PERFORMANCE WARNING:
# Thresholded incomplete Cholesky decomposition failed due to insufficient positive-definiteness of matrix A with parameters:
#     discard_threshold = 1.000000e-04
#     shift = 0.000000e+00
# Try decreasing discard_threshold or start with a larger shift
#
#       [11/15] Isolating foreground silhouette …
# 100% 18/18 [00:03<00:00,  5.98it/s]
# 100% 5/5 [00:01<00:00,  3.93it/s]
#       [12/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.11it/s]
# 100% 5/5 [00:01<00:00,  3.94it/s]
#       [13/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.25it/s]
# 100% 5/5 [00:01<00:00,  4.05it/s]
#       [14/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.29it/s]
# 100% 5/5 [00:01<00:00,  4.04it/s]
#       [15/15] Isolating foreground silhouette …
# 100% 18/18 [00:02<00:00,  6.06it/s]
# 100% 5/5 [00:01<00:00,  3.85it/s]
#
# [3/3] Class 2 'sheep' — Compiling 1000 domain-hardened training frames...
#       Assembled [1/1000] → sample_2_0000.jpg
#       Assembled [250/1000] → sample_2_0249.jpg
#       Assembled [500/1000] → sample_2_0499.jpg
#       Assembled [750/1000] → sample_2_0749.jpg
#       Assembled [1000/1000] → sample_2_0999.jpg
#
# ✅ Asset script execution successfully finished.

# %%
# !unzip animals-detection-images-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/Squirrel/013240b8dc5ed267.jpg
#   inflating: train/Squirrel/01998042bc8d9fc5.jpg
#   inflating: train/Squirrel/022a6508667c26a4.jpg
#   inflating: train/Squirrel/029dfca01a8a6c27.jpg
#   inflating: train/Squirrel/02a83d8659c234be.jpg
#   inflating: train/Squirrel/02b3690baaf911b8.jpg
#   inflating: train/Squirrel/02b7b759c7f92d7c.jpg
#   inflating: train/Squirrel/02d71b61109cbe80.jpg
#   inflating: train/Squirrel/0308ef4c641df4e5.jpg
#   inflating: train/Squirrel/031dda839ff54675.jpg
#   inflating: train/Squirrel/0346ada1fdb84d6f.jpg
#   inflating: train/Zebra/d354df4105a7ddd9.jpg
#   inflating: train/Zebra/d390bb0968ba26d6.jpg
#   inflating: train/Zebra/da16b12271a0f38b.jpg
#   inflating: train/Zebra/da68f65a6b69fa1d.jpg
#   inflating: train/Zebra/db80e348acfcf0ad.jpg
#   inflating: train/Zebra/e4a38e244a509ec7.jpg
#   inflating: train/Zebra/e9a7b197905ecddf.jpg
#   inflating: train/Zebra/ede7c8f72293df74.jpg
#   inflating: train/Zebra/efcf0b6eb7a99022.jpg
#   inflating: train/Zebra/f394d2e7a319656e.jpg
#   inflating: train/Zebra/f65b1055295737d6.jpg
#   inflating: train/Zebra/f6ff44677fa59c40.jpg
#   inflating: train/Zebra/fb2fc22e1e8d94b7.jpg
#   inflating: train/Zebra/fe4384825aa01b9f.jpg

# %%
# %%writefile train.py
"""
YOLOv8s Domain Blended Training Script
=======================================
"""

import sys
from pathlib import Path
from ultralytics import YOLO

def main():
    # 1. Mount Google Drive path validation
    gdrive_root = Path("/content/drive/MyDrive/yolo_backups")
    gdrive_root.mkdir(parents=True, exist_ok=True)

    dataset_yaml = Path("/content/combined_dataset/data.yaml")
    if not dataset_yaml.exists():
        print(f"[ERROR] Configuration profile not found at {dataset_yaml}")
        sys.exit(1)

    print("\n============================================================")
    print("  YOLOv8s Blended Domain Training Routine Initialized")
    print("============================================================\n")

    # 2. Spin up the advanced YOLOv8s core framework
    model = YOLO("yolov8s.pt")

    # 3. Fire training with defensive augmentation profiles
    results = model.train(
        data=str(dataset_yaml),
        epochs=60,                          # The sweet spot window to prevent Colab time-outs
        imgsz=640,                          # Matches native canvas dimensions
        batch=16,                           # Stable gradient step size
        device=0,                           # Direct GPU pointer execution
        workers=2,

        # ── DOMAIN SHIFT DEFENSES ────────────────────────────────────────────
        mosaic=1.0,                         # Multi-image stitching handles structural shifts
        close_mosaic=10,                    # Drop spatial distortion in the final 10 epochs
        mixup=0.20,                         # Transparent entity blending forces edge resilience
        scale=0.6,                          # Simulates distance scaling tracking
        perspective=0.0005,                 # Camera lens warp normalization

        # ── DRIVE CHECKPOINT BACKUPS ─────────────────────────────────────────
        project=str(gdrive_root),           # Saves checkpoints straight to your permanent Drive storage
        name="animal_detector_v8s_run",
        save=True,                          # Retains full tracking evaluations
        save_period=15,                     # Forces backup file compilation to Drive every 15 epochs
    )

    print("\n✅ Training pipeline successfully finished.")
    print(f"[INFO] Weights safely preserved in Drive: {gdrive_root}/animal_detector_v8s_run/weights")

if __name__ == "__main__":
    main()
# Out:
# Overwriting train.py

# %%
import os
from pathlib import Path
from PIL import Image

# ─────────────────────────────── CONFIG ──────────────────────────────────────
DATASET_ROOT = Path("/content/combined_dataset")

def normalize_all_labels():
    print("============================================================")
    print("  Executing Bounding Box Normalization Pipeline")
    print("============================================================\n")

    for split in ["train", "val"]:
        img_dir = DATASET_ROOT / "images" / split
        lbl_dir = DATASET_ROOT / "labels" / split

        if not img_dir.exists() or not lbl_dir.exists():
            continue

        print(f"[PROCESSING] Normalizing split data path: '{split}'...")
        fixed_count = 0

        for txt_path in lbl_dir.glob("*.txt"):
            # Find the matching image file
            img_path = None
            for ext in [".jpg", ".jpeg", ".png", ".JPG"]:
                possible_path = img_dir / f"{txt_path.stem}{ext}"
                if possible_path.exists():
                    img_path = possible_path
                    break

            if not img_path:
                continue # Skip if there's no matching image

            try:
                # Open image to get real structural pixel width and height
                with Image.open(img_path) as img:
                    img_w, img_h = img.size

                with open(txt_path, "r") as f:
                    lines = f.readlines()

                new_lines = []
                modified = False

                for line in lines:
                    parts = line.strip().split()
                    if len(parts) < 5:
                        continue

                    class_id = parts[0]
                    # Read absolute coordinates
                    coords = [float(x) for x in parts[1:5]]

                    # If any value is greater than 1.0, it is unnormalized absolute pixels
                    if any(c > 1.0 for c in coords):
                        modified = True

                        # Assuming common absolute format: [xmin, ymin, xmax, ymax]
                        xmin, ymin, xmax, ymax = coords

                        # Convert to width and height
                        box_w = xmax - xmin
                        box_h = ymax - ymin

                        # Find centers
                        cx = xmin + (box_w / 2.0)
                        cy = ymin + (box_h / 2.0)

                        # Normalize by image resolution limits
                        norm_cx = cx / img_w
                        norm_cy = cy / img_h
                        norm_w  = box_w / img_w
                        norm_h  = box_h / img_h

                        # Clip boundaries cleanly between 0.0 and 1.0 to ensure zero out-of-bounds float drifts
                        norm_cx = max(0.0, min(1.0, norm_cx))
                        norm_cy = max(0.0, min(1.0, norm_cy))
                        norm_w  = max(0.0, min(1.0, norm_w))
                        norm_h  = max(0.0, min(1.0, norm_h))

                        new_lines.append(f"{class_id} {norm_cx:.6f} {norm_cy:.6f} {norm_w:.6f} {norm_h:.6f}\n")
                    else:
                        new_lines.append(line)

                if modified:
                    with open(txt_path, "w") as f:
                        f.writelines(new_lines)
                    fixed_count += 1

            except Exception as e:
                print(f"   [ERROR] Failed to normalize layout {txt_path.name}: {e}")

        print(f"   └── Successfully scaled and normalized {fixed_count} labels inside '{split}'.")

    print("\n✅ Matrix alignment complete! Re-run train.py cell block.")

if __name__ == "__main__":
    normalize_all_labels()
# Out:
# ============================================================
#   Executing Bounding Box Normalization Pipeline
# ============================================================
#
# [PROCESSING] Normalizing split data path: 'train'...
#    └── Successfully scaled and normalized 370 labels inside 'train'.
# [PROCESSING] Normalizing split data path: 'val'...
#    └── Successfully scaled and normalized 0 labels inside 'val'.
#
# ✅ Matrix alignment complete! Re-run train.py cell block.

# %%
# !python train.py
# Out:
# ============================================================
#   YOLOv8s Blended Domain Training Routine Initialized
# ============================================================
#
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/combined_dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=animal_detector_v8s_run-3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolo_backups, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3, save_frames=False, save_json=False, save_period=15, save_txt=False, scale=0.6, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,136,761 parameters, 11,136,745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2062.2±1295.4 MB/s, size: 175.0 KB)
# train: Scanning /content/combined_dataset/labels/train... 3070 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3070/3070 2.1Kit/s 1.5s
# train: New cache created: /content/combined_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1493.1±858.3 MB/s, size: 169.5 KB)
# val: Scanning /content/combined_dataset/labels/val.cache... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 11.7Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      3.72G      1.139      1.615      1.398         36        640: 100% ━━━━━━━━━━━━ 192/192 2.2it/s 1:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.8s
#                    all        300        300      0.747      0.732      0.845      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      4
/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/last.pt, 22.5MB
# Optimizer stripped from /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/best.pt, 22.5MB
#
# Validating /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/best.pt...
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.0it/s 5.1s
#                    all        300        300      0.992      0.997      0.991       0.97
#                    fox        100        100      0.989          1      0.994      0.967
#                leopard        100        100      0.993          1      0.995      0.973
#                  sheep        100        100      0.993       0.99      0.985      0.971
# Speed: 0.2ms preprocess, 4.9ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3
#
# ✅ Training pipeline successfully finished.
# [INFO] Weights safely preserved in Drive: /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run/weights

# %%
# %%writefile predict.py
import argparse
import sys
from pathlib import Path

from PIL import Image
from ultralytics import YOLO


# ─────────────────────────────── CONFIG ──────────────────────────────────────

DEFAULT_WEIGHTS = Path("/content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/best.pt")
DEFAULT_CONF    = 0.25
DEFAULT_IOU     = 0.45
IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp", ".tiff"}


# ─────────────────────────────── INFERENCE ───────────────────────────────────

def predict_single(image_path: Path, model: YOLO, conf: float, iou: float, save: bool) -> dict:
    """
    Run inference on one image.
    Returns a result dict for summary printing.
    """
    results = model.predict(source=str(image_path), conf=conf, iou=iou, verbose=False)
    r     = results[0]
    boxes = r.boxes

    # Ground truth is derived from the immediate parent folder name
    ground_truth = image_path.parent.name.lower()

    if boxes is None or len(boxes) == 0:
        print(f"  {image_path.name:<40}  →  no detection (conf≥{conf:.0%}) [GT: {ground_truth}]")
        return {"file": image_path.name, "class": None, "conf": None, "correct": False}

    best_idx   = int(boxes.conf.argmax())
    best_cls   = int(boxes.cls[best_idx])
    best_conf  = float(boxes.conf[best_idx])
    class_name = r.names[best_cls]

    # Evaluate prediction accuracy against folder name structure
    is_correct = (class_name.lower() == ground_truth)
    match_status = "✓ MATCH" if is_correct else "✗ MISMATCH"

    print(f"  {image_path.name:<40}  →  This is a {class_name} image  "
          f"(conf: {best_conf:.1%})  [{match_status} with '{ground_truth}']")

    if save:
        out_path = image_path.parent / f"{image_path.stem}_predicted{image_path.suffix}"
        Image.fromarray(r.plot()[..., ::-1]).save(out_path)
        print(f"  {'':40}     saved → {out_path.name}")

    return {"file": image_path.name, "class": class_name, "conf": best_conf, "correct": is_correct}


def predict_folder(folder: Path, model: YOLO, conf: float, iou: float, save: bool) -> None:
    images = sorted([p for p in folder.iterdir() if p.suffix.lower() in IMAGE_EXTENSIONS])

    if not images:
        print(f"[ERROR] No images found in {folder}")
        print(f"  Supported formats: {', '.join(IMAGE_EXTENSIONS)}")
        sys.exit(1)

    print(f"\n[INFO] Found {len(images)} image(s) in {folder}\n")
    print(f"  {'File':<40}     Prediction")
    print(f"  {'-'*40}     {'-'*55}")

    results = [predict_single(img, model, conf, iou, save) for img in images]

    # ── Summary & Accuracy Calculation ────────────────────────────────────────
    detected     = [r for r in results if r["class"] is not None]
    no_detect    = [r for r in results if r["class"] is None]
    correct_cnt  = sum(1 for r in results if r["correct"])

    # Accuracy string calculation handles edge conditions smoothly
    accuracy_pct = (correct_cnt / len(results)) * 100 if results else 0.0

    class_counts = {}
    for r in detected:
        class_counts[r["class"]] = class_counts.get(r["class"], 0) + 1

    print(f"\n── Summary {'─'*50}")
    print(f"  Target Folder  : {folder.name}")
    print(f"  Total images   : {len(results)}")
    print(f"  Detected       : {len(detected)}")
    print(f"  No detection   : {len(no_detect)}")
    print(f"  Correct Match  : {correct_cnt} / {len(results)}")
    print(f"  Folder Accuracy: {accuracy_pct:.2f}%") # Adds clean accuracy output
    if class_counts:
        print(f"  Breakdown      :")
        for cls, count in sorted(class_counts.items()):
            print(f"    {cls:<20} {count} image(s)")
    print(f"{'─'*62}")


# ─────────────────────────────── CLI ─────────────────────────────────────────

def parse_args() -> argparse.Namespace:
    parser = argparse.ArgumentParser(
        description="Detect and classify animals using the trained YOLOv8 model"
    )

    group = parser.add_mutually_exclusive_group(required=True)
    group.add_argument("--image",  help="Path to a single input image")
    group.add_argument("--folder", help="Path to a folder of images")

    parser.add_argument("--weights", default=str(DEFAULT_WEIGHTS),
                        help=f"Path to trained weights (default: {DEFAULT_WEIGHTS})")
    parser.add_argument("--conf", type=float, default=DEFAULT_CONF,
                        help=f"Confidence threshold 0-1 (default: {DEFAULT_CONF})")
    parser.add_argument("--iou", type=float, default=DEFAULT_IOU,
                        help=f"IoU threshold for NMS (default: {DEFAULT_IOU})")
    parser.add_argument("--save", action="store_true",
                        help="Save annotated images alongside originals")
    return parser.parse_args()


# ─────────────────────────────── MAIN ────────────────────────────────────────

if __name__ == "__main__":
    args    = parse_args()
    weights = Path(args.weights)

    if not weights.exists():
        print(f"[ERROR] Model weights not found: {weights}")
        print("        Run  python train.py  first.")
        sys.exit(1)

    print(f"[INFO] Loading model from: {weights}")
    model = YOLO(str(weights))

    if args.image:
        image_path = Path(args.image)
        if not image_path.exists():
            print(f"[ERROR] Image not found: {image_path}")
            sys.exit(1)
        print()
        r = predict_single(image_path, model, args.conf, args.iou, args.save)
        if r["class"]:
            print(f"\nThis is a {r['class']} image  (conf: {r['conf']:.1%})")

    elif args.folder:
        folder = Path(args.folder)
        if not folder.exists():
            print(f"[ERROR] Folder not found: {folder}")
            sys.exit(1)
        predict_folder(folder, model, args.conf, args.iou, args.save)
# Out:
# Writing predict.py

# %%
# !python predict.py --folder sheep
# Out:
# [INFO] Loading model from: /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/best.pt
#
# [INFO] Found 203 image(s) in sheep
#
#   File                                         Prediction
#   ----------------------------------------     -------------------------------------------------------
#   sheep0.png                                →  This is a sheep image  (conf: 76.6%)  [✓ MATCH with 'sheep']
#   sheep1.png                                →  This is a sheep image  (conf: 80.8%)  [✓ MATCH with 'sheep']
#   sheep10.png                               →  This is a sheep image  (conf: 83.9%)  [✓ MATCH with 'sheep']
#   sheep100.png                              →  This is a sheep image  (conf: 89.3%)  [✓ MATCH with 'sheep']
#   sheep101.png                              →  This is a sheep image  (conf: 89.9%)  [✓ MATCH with 'sheep']
#   sheep102.png                              →  This is a sheep image  (conf: 86.1%)  [✓ MATCH with 'sheep']
#   sheep103.png                              →  This is a sheep image  (conf: 88.9%)  [✓ MATCH with 'sheep']
#   sheep104.png                              →  This is a sheep image  (conf: 90.8%)  [✓ MATCH with 'sheep']
#   sheep105.png                              →  This is a sheep image  (conf: 89.6%)  [✓ MATCH with 'sheep']
#   sheep106.png                              →  This is a sheep image  (conf: 74.4%)  [✓ MATCH with 'sheep']
#   sheep107.png                              →  This is a sheep image  (conf: 83.4%)  [✓ MATCH with 'sheep']
#   sheep108.png                              →  This is a sheep image  (conf: 83.2%)  [✓ MATCH with 'sheep']
#   sheep109.png                              →  This is a sheep image  (conf: 82.9%)  [✓ MATCH with 'sheep']
#   sheep11.png                               →  This is a sheep image  (conf: 91.8%)  [✓ MATCH with 'sheep']
#   sheep110.png                              →  This is a sheep image  (conf: 77.3%)  [✓ MATCH with 'sheep']
#   sheep111.png                              →  This is a sheep image  (conf: 89.2%)  [✓ MATCH with 'sheep']
#   sheep112.png                              →  This is a sheep image  (conf: 86.8%)  [✓ MATCH with 'sheep']
#   sheep113.png                              →  This is a sheep image  (conf: 87.2%)  [✓ MATCH with 'sheep']
#   sheep114.png                              →  This is a sheep image  (conf: 92.2%)  [✓ MATCH with 'sheep']
#   sheep115.png                              →  This is a sheep image  (conf: 88.5%)  [✓ MATCH with 'sheep']
#   sheep116.png                              →  This is a sheep image  (conf: 91.3%)  [✓ MATCH with 'sheep']
#   sheep117.png                              →  This is a sheep image  (conf: 90.4%)  [✓ MATCH with 'sheep']
#   sheep118.png                              →  This is a sheep image  (conf: 59.7%)  [✓ MATCH with 'sheep']
#   sheep119.png                              →  This is a sheep image  (conf: 90.2%)  [✓ MATCH with 'sheep']
#   sheep12.png                               →  This is a sheep image  (conf: 93.5%)  [✓ MATCH with 'sheep']
#   sheep120.png                              →  This is a sheep image  (conf: 79.9%)  [✓ MATCH with 'sheep']
#   sheep121.png                              →  This is a sheep image  (conf: 94.1%)  [✓ MATCH with 'sheep']
#   sheep122.png                              →  This is a sheep image  (conf: 88.4%)  [✓ MATCH with 'sheep']
#   sheep123.png                              →  This is a sheep image  (conf: 88.4%)  [✓ MATCH with 'sheep']
#   sheep124.png                              →  This is a sheep image  (conf: 92.2%)  [✓ MATCH with 'sheep']
#   sheep125.png                              →  This is a sheep image  (conf: 87.9%)  [✓ MATCH with 'sheep']
#   sheep126.png                              →  This is a sheep image  (conf: 89.3%)  [✓ MATCH with 'sheep']
#   sheep127.png                              →  This is a sheep image  (conf: 91.7%)  [✓ MATCH with 'sheep']
#   sheep128.png                              →  This is a sheep image  (conf: 88.0%)  [✓ MATCH with 'sheep']
#   sheep129.png                              →  This is a sheep image  (conf: 88.4%)  [✓ MATCH with 'sheep']
#   sheep13.png                               →  This is a sheep image  (conf: 76.6%)  [✓ MATCH with 'sheep']
#   sheep130.png                              →  This is a sheep image  (conf: 34.1%)  [✓ MATCH with 'sheep']
#   sheep131.png                              →  This is a sheep image  (conf: 81.3%)  [✓ MATCH with 'sheep']
#   sheep132.png                              →  This is a sheep image  (conf: 83.5%)  [✓ MATCH with 'sheep']
#   sheep133.png                              →  This is a sheep image  (conf: 85.2%)  [✓ MATCH with 'sheep']
#   sheep134.png                              →  This is a sheep image  (conf: 88.2%)  [✓ MATCH with 'sheep']
#   sheep135.png                              →  This is a sheep image  (conf: 90.0%)  [✓ MATCH with 'sheep']
#   sheep136.png                              →  This is a sheep image  (conf: 78.0%)  [✓ MATCH with 'sheep']
#   sheep137.png                              →  This is a sheep image  (conf: 91.7%)  [✓ MATCH with 'sheep']
#   sheep138.png                              →  This is a sheep image  (conf: 89.0%)  [✓ MATCH with 'sheep']
#   sheep139.png                              →  This is a sheep image  (conf: 92.6%)  [✓ MATCH with 'sheep']
#   sheep14.png                               →  This is a sheep image  (conf: 86.8%)  [✓ MATCH with 'sheep']
#   sheep140.png                              →  This is a sheep image  (conf: 93.7%)  [✓ MATCH with 'sheep']
#   sheep141.png                              →  This is a sheep image  (conf: 93.3%)  [✓ MATCH with 'sheep']
#   sheep142.png                              →  This is a sheep image  (conf: 87.6%)  [✓ MATCH with 'sheep']
#   sheep143.png                              →  This is a sheep image  (conf: 86.3%)  [✓ MATCH with 'sheep']
#   sheep144.png                              →  This is a fox image  (conf: 38.4%)  [✗ MISMATCH with 'sheep']
#   sheep145.png                              →  This is a sheep image  (conf: 77.2%)  [✓ MATCH with 'sheep']
#   sheep146.png                              →  This is a sheep image  (conf: 86.9%)  [✓ MATCH with 'sheep']
#   sheep147.png                              →  This is a sheep image  (conf: 73.6%)  [✓ MATCH with 'sheep']
#   sheep148.png                              →  This is a sheep image  (conf: 93.4%)  [✓ MATCH with 'sheep']
#   sheep149.png                              →  This is a sheep image  (conf: 81.1%)  [✓ MATCH with 'sheep']
#   sheep15.png                               →  This is a sheep image  (conf: 93.6%)  [✓ MATCH with 'sheep']
#   sheep150.png                              →  This is a sheep image  (conf: 93.2%)  [✓ MATCH with 'sheep']
#   sheep151.png                              →  This is a sheep image  (conf: 87.6%)  [✓ MATCH with 'sheep']
#   sheep152.png                              →  This is a sheep image  (conf: 93.3%)  [✓ MATCH with 'sheep']
#   sheep153.png                              →  This is a sheep image  (conf: 90.2%)  [✓ MATCH with 'sheep']
#   sheep154.png                              →  This is a sheep image  (conf: 70.7%)  [✓ MATCH with 'sheep']
#   sheep155.png                              →  This is a sheep image  (conf: 90.9%)  [✓ MATCH with 'sheep']
#   sheep156.png                              →  This is a sheep image  (conf: 89.4%)  [✓ MATCH with 'sheep']
#   sheep157.png                              →  This is a sheep image  (conf: 89.9%)  [✓ MATCH with 'sheep']
#   sheep158.png                              →  This is a sheep image  (conf: 91.7%)  [✓ MATCH with 'sheep']
#   sheep159.png                              →  This is a sheep image  (conf: 93.1%)  [✓ MATCH with 'sheep']
#   sheep16.png                               →  This is a sheep image  (conf: 89.4%)  [✓ MATCH with 'sheep']
#   sheep160.png                              →  This is a sheep image  (conf: 86.8%)  [✓ MATCH with 'sheep']
#   sheep161.png                              →  This is a sheep image  (conf: 90.7%)  [✓ MATCH with 'sheep']
#   sheep162.png                              →  This is a sheep image  (conf: 74.6%)  [✓ MATCH with 'sheep']
#   sheep163.png                              →  This is a sheep image  (conf: 91.0%)  [✓ MATCH with 'sheep']
#   sheep164.png                              →  This is a sheep image  (conf: 93.8%)  [✓ MATCH with 'sheep']
#   sheep165.png                              →  This is a sheep image  (conf: 90.6%)  [✓ MATCH with 'sheep']
#   sheep166.png                              →  This is a sheep image  (conf: 90.3%)  [✓ MATCH with 'sheep']
#   sheep167.png                              →  This is a sheep image  (conf: 84.4%)  [✓ MATCH with 'sheep']
#   sheep168.png                              →  This is a sheep image  (conf: 93.9%)  [✓ MATCH with 'sheep']
#   sheep169.png                              →  This is a sheep image  (conf: 93.0%)  [✓ MATCH with 'sheep']
#   sheep17.png                               →  This is a sheep image  (conf: 79.2%)  [✓ MATCH with 'sheep']
#   sheep170.png                              →  This is a sheep image  (conf: 83.8%)  [✓ MATCH with 'sheep']
#   sheep171.png                              →  This is a sheep image  (conf: 69.6%)  [✓ MATCH with 'sheep']
#   sheep172.png                              →  This is a sheep image  (conf: 90.5%)  [✓ MATCH with 'sheep']
#   sheep173.png                              →  This is a fox image  (conf: 52.4%)  [✗ MISMATCH with 'sheep']
#   sheep174.png                              →  This is a sheep image  (conf: 90.5%)  [✓ MATCH with 'sheep']
#   sheep175.png                              →  This is a sheep image  (conf: 89.5%)  [✓ MATCH with 'sheep']
#   sheep176.png                              →  This is a sheep image  (conf: 87.0%)  [✓ MATCH with 'sheep']
#   sheep177.png                              →  This is a sheep image  (conf: 37.3%)  [✓ MATCH with 'sheep']
#   sheep178.png                              →  This is a sheep image  (conf: 90.3%)  [✓ MATCH with 'sheep']
#   sheep179.png                              →  This is a sheep image  (conf: 88.2%)  [✓ MATCH with 'sheep']
#   sheep18.png                               →  This is a sheep image  (conf: 93.0%)  [✓ MATCH with 'sheep']
#   sheep180.png                              →  This is a sheep image  (conf: 93.3%)  [✓ MATCH with 'sheep']
#   sheep181.png                              →  This is a sheep image  (conf: 87.7%)  [✓ MATCH with 'sheep']
#   sheep182.png                              →  This is a sheep image  (conf: 90.1%)  [✓ MATCH with 'sheep']
#   sheep183.png                              →  This is a sheep image  (conf: 90.5%)  [✓ MATCH with 'sheep']
#   sheep184.png                              →  This is a sheep image  (conf: 93.9%)  [✓ MATCH with 'sheep']
#   sheep185.png                              →  This is a sheep image  (conf: 75.9%)  [✓ MATCH with 'sheep']
#   sheep186.png                              →  This is a sheep image  (conf: 92.8%)  [✓ MATCH with 'sheep']
#   sheep187.png                              →  This is a sheep image  (conf: 88.9%)  [✓ MATCH with 'sheep']
#   sheep188.png                              →  This is a sheep image  (conf: 91.5%)  [✓ MATCH with 'sheep']
#   sheep189.png                              →  This is a sheep image  (conf: 88.8%)  [✓ MATCH with 'sheep']
#   sheep19.png                               →  This is a sheep image  (conf: 91.3%)  [✓ MATCH with 'sheep']
#   sheep190.png                              →  This is a sheep image  (conf: 87.0%)  [✓ MATCH with 'sheep']
#   sheep191.png                              →  This is a sheep image  (conf: 70.4%)  [✓ MATCH with 'sheep']
#   sheep192.png                              →  This is a sheep image  (conf: 80.6%)  [✓ MATCH with 'sheep']
#   sheep193.png                              →  This is a sheep image  (conf: 78.0%)  [✓ MATCH with 'sheep']
#   sheep194.png                              →  This is a sheep image  (conf: 84.4%)  [✓ MATCH with 'sheep']
#   sheep195.png                              →  This is a sheep image  (conf: 90.2%)  [✓ MATCH with 'sheep']
#   sheep196.png                              →  This is a sheep image  (conf: 94.1%)  [✓ MATCH with 'sheep']
#   sheep197.png                              →  This is a sheep image  (conf: 85.8%)  [✓ MATCH with 'sheep']
#   sheep198.png                              →  This is a sheep image  (conf: 89.2%)  [✓ MATCH with 'sheep']
#   sheep199.png                              →  This is a sheep image  (conf: 90.2%)  [✓ MATCH with 'sheep']
#   sheep2.png                                →  This is a sheep image  (conf: 82.8%)  [✓ MATCH with 'sheep']
#   sheep20.png                               →  This is a sheep image  (conf: 75.1%)  [✓ MATCH with 'sheep']
#   sheep200.png                              →  This is a sheep image  (conf: 92.0%)  [✓ MATCH with 'sheep']
#   sheep201.png                              →  This is a sheep image  (conf: 90.9%)  [✓ MATCH with 'sheep']
#   sheep202.png                              →  This is a sheep image  (conf: 90.1%)  [✓ MATCH with 'sheep']
#   sheep21.png                               →  This is a sheep image  (conf: 92.5%)  [✓ MATCH with 'sheep']
#   sheep22.png                               →  This is a sheep image  (conf: 84.4%)  [✓ MATCH with 'sheep']
#   sheep23.png                               →  This is a sheep image  (conf: 87.8%)  [✓ MATCH with 'sheep']
#   sheep24.png                               →  This is a sheep image  (conf: 93.7%)  [✓ MATCH with 'sheep']
#   sheep25.png                               →  This is a sheep image  (conf: 93.0%)  [✓ MATCH with 'sheep']
#   sheep26.png                               →  This is a sheep image  (conf: 93.0%)  [✓ MATCH with 'sheep']
#   sheep27.png                               →  This is a sheep image  (conf: 87.2%)  [✓ MATCH with 'sheep']
#   sheep28.png                               →  This is a sheep image  (conf: 88.0%)  [✓ MATCH with 'sheep']
#   sheep29.png                               →  This is a sheep image  (conf: 89.8%)  [✓ MATCH with 'sheep']
#   sheep3.png                                →  This is a sheep image  (conf: 88.5%)  [✓ MATCH with 'sheep']
#   sheep30.png                               →  This is a sheep image  (conf: 87.2%)  [✓ MATCH with 'sheep']
#   sheep31.png                               →  This is a sheep image  (conf: 74.9%)  [✓ MATCH with 'sheep']
#   sheep32.png                               →  This is a sheep image  (conf: 93.6%)  [✓ MATCH with 'sheep']
#   sheep33.png                               →  This is a sheep image  (conf: 89.3%)  [✓ MATCH with 'sheep']
#   sheep34.png                               →  This is a sheep image  (conf: 76.5%)  [✓ MATCH with 'sheep']
#   sheep35.png                               →  This is a sheep image  (conf: 87.9%)  [✓ MATCH with 'sheep']
#   sheep36.png                               →  This is a sheep image  (conf: 92.3%)  [✓ MATCH with 'sheep']
#   sheep37.png                               →  This is a sheep image  (conf: 92.1%)  [✓ MATCH with 'sheep']
#   sheep38.png                               →  This is a sheep image  (conf: 91.6%)  [✓ MATCH with 'sheep']
#   sheep39.png                               →  This is a sheep image  (conf: 63.7%)  [✓ MATCH with 'sheep']
#   sheep4.png                                →  This is a sheep image  (conf: 79.6%)  [✓ MATCH with 'sheep']
#   sheep40.png                               →  This is a sheep image  (conf: 83.3%)  [✓ MATCH with 'sheep']
#   sheep41.png                               →  This is a sheep image  (conf: 89.7%)  [✓ MATCH with 'sheep']
#   sheep42.png                               →  This is a sheep image  (conf: 90.2%)  [✓ MATCH with 'sheep']
#   sheep43.png                               →  This is a sheep image  (conf: 88.2%)  [✓ MATCH with 'sheep']
#   sheep44.png                               →  This is a sheep image  (conf: 86.7%)  [✓ MATCH with 'sheep']
#   sheep45.png                               →  This is a sheep image  (conf: 77.0%)  [✓ MATCH with 'sheep']
#   sheep46.png                               →  This is a sheep image  (conf: 84.6%)  [✓ MATCH with 'sheep']
#   sheep47.png                               →  This is a sheep image  (conf: 85.2%)  [✓ MATCH with 'sheep']
#   sheep48.png                               →  This is a sheep image  (conf: 92.1%)  [✓ MATCH with 'sheep']
#   sheep49.png                               →  This is a sheep image  (conf: 93.7%)  [✓ MATCH with 'sheep']
#   sheep5.png                                →  This is a sheep image  (conf: 87.7%)  [✓ MATCH with 'sheep']
#   sheep50.png                               →  This is a sheep image  (conf: 89.1%)  [✓ MATCH with 'sheep']
#   sheep51.png                               →  This is a sheep image  (conf: 28.3%)  [✓ MATCH with 'sheep']
#   sheep52.png                               →  This is a sheep image  (conf: 86.8%)  [✓ MATCH with 'sheep']
#   sheep53.png                               →  This is a sheep image  (conf: 80.7%)  [✓ MATCH with 'sheep']
#   sheep54.png                               →  This is a sheep image  (conf: 87.8%)  [✓ MATCH with 'sheep']
#   sheep55.png                               →  This is a sheep image  (conf: 93.8%)  [✓ MATCH with 'sheep']
#   sheep56.png                               →  This is a sheep image  (conf: 78.8%)  [✓ MATCH with 'sheep']
#   sheep57.png                               →  This is a sheep image  (conf: 84.5%)  [✓ MATCH with 'sheep']
#   sheep58.png                               →  This is a sheep image  (conf: 81.4%)  [✓ MATCH with 'sheep']
#   sheep59.png                               →  This is a sheep image  (conf: 89.4%)  [✓ MATCH with 'sheep']
#   sheep6.png                                →  This is a sheep image  (conf: 92.5%)  [✓ MATCH with 'sheep']
#   sheep60.png                               →  This is a sheep image  (conf: 94.5%)  [✓ MATCH with 'sheep']
#   sheep61.png                               →  This is a sheep image  (conf: 85.6%)  [✓ MATCH with 'sheep']
#   sheep62.png                               →  This is a sheep image  (conf: 94.0%)  [✓ MATCH with 'sheep']
#   sheep63.png                               →  This is a sheep image  (conf: 89.2%)  [✓ MATCH with 'sheep']
#   sheep64.png                               →  This is a sheep image  (conf: 90.2%)  [✓ MATCH with 'sheep']
#   sheep65.png                               →  This is a sheep image  (conf: 95.0%)  [✓ MATCH with 'sheep']
#   sheep66.png                               →  This is a sheep image  (conf: 78.4%)  [✓ MATCH with 'sheep']
#   sheep67.png                               →  This is a sheep image  (conf: 94.4%)  [✓ MATCH with 'sheep']
#   sheep68.png                               →  This is a sheep image  (conf: 64.5%)  [✓ MATCH with 'sheep']
#   sheep69.png                               →  This is a sheep image  (conf: 87.9%)  [✓ MATCH with 'sheep']
#   sheep7.png                                →  This is a sheep image  (conf: 91.0%)  [✓ MATCH with 'sheep']
#   sheep70.png                               →  This is a sheep image  (conf: 92.8%)  [✓ MATCH with 'sheep']
#   sheep71.png                               →  This is a sheep image  (conf: 92.1%)  [✓ MATCH with 'sheep']
#   sheep72.png                               →  This is a sheep image  (conf: 90.5%)  [✓ MATCH with 'sheep']
#   sheep73.png                               →  This is a sheep image  (conf: 84.3%)  [✓ MATCH with 'sheep']
#   sheep74.png                               →  This is a sheep image  (conf: 83.2%)  [✓ MATCH with 'sheep']
#   sheep75.png                               →  This is a sheep image  (conf: 91.3%)  [✓ MATCH with 'sheep']
#   sheep76.png                               →  This is a sheep image  (conf: 83.4%)  [✓ MATCH with 'sheep']
#   sheep77.png                               →  This is a sheep image  (conf: 88.2%)  [✓ MATCH with 'sheep']
#   sheep78.png                               →  This is a sheep image  (conf: 86.0%)  [✓ MATCH with 'sheep']
#   sheep79.png                               →  This is a sheep image  (conf: 92.5%)  [✓ MATCH with 'sheep']
#   sheep8.png                                →  This is a sheep image  (conf: 83.8%)  [✓ MATCH with 'sheep']
#   sheep80.png                               →  This is a sheep image  (conf: 82.4%)  [✓ MATCH with 'sheep']
#   sheep81.png                               →  This is a sheep image  (conf: 82.4%)  [✓ MATCH with 'sheep']
#   sheep82.png                               →  This is a sheep image  (conf: 85.4%)  [✓ MATCH with 'sheep']
#   sheep83.png                               →  This is a sheep image  (conf: 93.5%)  [✓ MATCH with 'sheep']
#   sheep84.png                               →  This is a sheep image  (conf: 93.4%)  [✓ MATCH with 'sheep']
#   sheep85.png                               →  This is a sheep image  (conf: 83.4%)  [✓ MATCH with 'sheep']
#   sheep86.png                               →  This is a sheep image  (conf: 86.7%)  [✓ MATCH with 'sheep']
#   sheep87.png                               →  This is a sheep image  (conf: 64.7%)  [✓ MATCH with 'sheep']
#   sheep88.png                               →  This is a sheep image  (conf: 90.6%)  [✓ MATCH with 'sheep']
#   sheep89.png                               →  This is a sheep image  (conf: 94.4%)  [✓ MATCH with 'sheep']
#   sheep9.png                                →  This is a sheep image  (conf: 92.7%)  [✓ MATCH with 'sheep']
#   sheep90.png                               →  This is a sheep image  (conf: 88.8%)  [✓ MATCH with 'sheep']
#   sheep91.png                               →  This is a sheep image  (conf: 89.2%)  [✓ MATCH with 'sheep']
#   sheep92.png                               →  This is a sheep image  (conf: 91.6%)  [✓ MATCH with 'sheep']
#   sheep93.png                               →  This is a sheep image  (conf: 93.8%)  [✓ MATCH with 'sheep']
#   sheep94.png                               →  This is a sheep image  (conf: 84.4%)  [✓ MATCH with 'sheep']
#   sheep95.png                               →  This is a sheep image  (conf: 94.1%)  [✓ MATCH with 'sheep']
#   sheep96.png                               →  This is a sheep image  (conf: 91.7%)  [✓ MATCH with 'sheep']
#   sheep97.png                               →  This is a sheep image  (conf: 34.5%)  [✓ MATCH with 'sheep']
#   sheep98.png                               →  This is a sheep image  (conf: 88.6%)  [✓ MATCH with 'sheep']
#   sheep99.png                               →  This is a sheep image  (conf: 87.4%)  [✓ MATCH with 'sheep']
#
# ── Summary ──────────────────────────────────────────────────
#   Target Folder  : sheep
#   Total images   : 203
#   Detected       : 203
#   No detection   : 0
#   Correct Match  : 201 / 203
#   Folder Accuracy: 99.01%
#   Breakdown      :
#     fox                  2 image(s)
#     sheep                201 image(s)
# ──────────────────────────────────────────────────────────────

# %%
# !python predict.py --folder leopard
# Out:
# [INFO] Loading model from: /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/best.pt
#
# [INFO] Found 166 image(s) in leopard
#
#   File                                         Prediction
#   ----------------------------------------     -------------------------------------------------------
#   04f35ff2-90c0-4f3f-b8d8-9b0f6973c093.jpg  →  This is a leopard image  (conf: 81.0%)  [✓ MATCH with 'leopard']
#   0528a045-90f6-4b91-9cfe-ab95e9f77894.jpg  →  This is a sheep image  (conf: 38.1%)  [✗ MISMATCH with 'leopard']
#   05530504-290b-47f0-9216-473575014fb8.jpg  →  This is a leopard image  (conf: 77.6%)  [✓ MATCH with 'leopard']
#   082492f9-1830-4499-87a8-69d206f7ea58.jpg  →  This is a leopard image  (conf: 91.0%)  [✓ MATCH with 'leopard']
#   08a587a5-7363-4f4f-9588-a84ca1bddc35.jpg  →  This is a leopard image  (conf: 91.0%)  [✓ MATCH with 'leopard']
#   09248fd9-1134-4712-bde9-d375b29dd46a.jpg  →  This is a leopard image  (conf: 93.2%)  [✓ MATCH with 'leopard']
#   0cd936b5-b009-4ed5-9636-ecb6ca57f7e2.jpg  →  This is a leopard image  (conf: 83.2%)  [✓ MATCH with 'leopard']
#   0d4a1cb1-8e56-4840-baaf-583f20160326.jpg  →  This is a leopard image  (conf: 38.4%)  [✓ MATCH with 'leopard']
#   1200462c-1081-4c2c-a783-f20f02f16cf3.jpg  →  This is a leopard image  (conf: 90.6%)  [✓ MATCH with 'leopard']
#   1272a02f-9ba2-4bfa-a0ee-359b008cbacb.jpg  →  This is a leopard image  (conf: 91.7%)  [✓ MATCH with 'leopard']
#   1319523b-ffed-41f3-8a20-e4d4e102d193.jpg  →  This is a leopard image  (conf: 90.3%)  [✓ MATCH with 'leopard']
#   15d500b3-3a15-450c-8757-edd1d214f648.jpg  →  This is a leopard image  (conf: 90.1%)  [✓ MATCH with 'leopard']
#   1663f152-e865-4ab7-abe0-b52775699ff9.jpg  →  This is a leopard image  (conf: 88.8%)  [✓ MATCH with 'leopard']
#   16b67b9e-c849-4362-9ee8-733e07a98c5d.jpg  →  This is a leopard image  (conf: 64.3%)  [✓ MATCH with 'leopard']
#   16c9bdf2-3cd3-4cb4-81ed-e4432b49e158.jpg  →  This is a sheep image  (conf: 80.2%)  [✗ MISMATCH with 'leopard']
#   192ef6fa-bbad-4cc2-91cf-a3697c1e4665.jpg  →  This is a leopard image  (conf: 70.1%)  [✓ MATCH with 'leopard']
#   1a7d6f5c-a033-4bb9-b77c-41cdf7373581.jpg  →  This is a leopard image  (conf: 83.9%)  [✓ MATCH with 'leopard']
#   1b3e5c50-8396-4124-b735-e8b7984f7a4f.jpg  →  This is a leopard image  (conf: 78.5%)  [✓ MATCH with 'leopard']
#   1ba673e2-56d4-41f0-b1cf-67741cf4f3ba.jpg  →  This is a leopard image  (conf: 92.2%)  [✓ MATCH with 'leopard']
#   1c64070d-619e-40a8-ae5d-ba5b732d463f.jpg  →  This is a leopard image  (conf: 76.4%)  [✓ MATCH with 'leopard']
#   1d656279-fbbc-4044-a7f2-054c83780f77.jpg  →  This is a leopard image  (conf: 77.8%)  [✓ MATCH with 'leopard']
#   1d6be1bf-79a1-45ea-9f86-df3b4cf2c759.jpg  →  This is a leopard image  (conf: 83.8%)  [✓ MATCH with 'leopard']
#   1dbc21ef-3e2a-481b-9dfd-293df54b1261.jpg  →  This is a leopard image  (conf: 84.4%)  [✓ MATCH with 'leopard']
#   1dbf0b07-598a-453b-b2a7-a6fe61ff3678.jpg  →  This is a leopard image  (conf: 86.1%)  [✓ MATCH with 'leopard']
#   22d8e35e-fe87-4aa0-becb-637e4574eda6.jpg  →  This is a leopard image  (conf: 87.5%)  [✓ MATCH with 'leopard']
#   233a24a3-0905-447a-b0aa-073a4c82cc68.jpg  →  This is a leopard image  (conf: 68.8%)  [✓ MATCH with 'leopard']
#   2863f99b-a407-4337-a787-8c28bc9d735f.jpg  →  This is a leopard image  (conf: 93.3%)  [✓ MATCH with 'leopard']
#   28b83ec0-9c92-4856-b00a-44f60208f086.jpg  →  This is a leopard image  (conf: 91.9%)  [✓ MATCH with 'leopard']
#   2ab1c9cb-9ba6-4994-a0ed-a53c2cf0deb7.jpg  →  This is a leopard image  (conf: 90.4%)  [✓ MATCH with 'leopard']
#   2b05bd09-99e8-45fb-a596-d4e86126bc4e.jpg  →  This is a leopard image  (conf: 88.5%)  [✓ MATCH with 'leopard']
#   2b0ec54c-2a4a-46b8-8a6c-1f4f542973d5.jpg  →  This is a leopard image  (conf: 87.1%)  [✓ MATCH with 'leopard']
#   2c674d96-8079-4def-aec7-9ba5f40c82cc.jpg  →  This is a leopard image  (conf: 89.7%)  [✓ MATCH with 'leopard']
#   2fe96a57-25ff-45ca-985a-15a0ddb8836b.jpg  →  This is a leopard image  (conf: 86.0%)  [✓ MATCH with 'leopard']
#   336fb151-295d-4294-a4e3-1c47cfa12b68.jpg  →  This is a leopard image  (conf: 88.6%)  [✓ MATCH with 'leopard']
#   34ccf783-f450-4e64-be54-0ae3dc754d62.jpg  →  This is a leopard image  (conf: 91.6%)  [✓ MATCH with 'leopard']
#   38e26ae1-e7a3-4f5e-a4d2-3c93b33326d9.jpg  →  This is a leopard image  (conf: 88.0%)  [✓ MATCH with 'leopard']
#   394aa98b-6d79-4d49-8570-0c44237699f5.jpg  →  This is a leopard image  (conf: 75.9%)  [✓ MATCH with 'leopard']
#   3a5c0acd-3f39-4999-8da8-3b8b6e379301.jpg  →  This is a leopard image  (conf: 94.1%)  [✓ MATCH with 'leopard']
#   3afa826c-3595-436f-b9e4-b21c6e2bd782.jpg  →  This is a leopard image  (conf: 83.0%)  [✓ MATCH with 'leopard']
#   3bfcdc30-4278-4151-81c3-0e4b45153d30.jpg  →  This is a leopard image  (conf: 90.4%)  [✓ MATCH with 'leopard']
#   3d14c79b-3626-49f5-830c-4de88d97678c.jpg  →  This is a leopard image  (conf: 89.4%)  [✓ MATCH with 'leopard']
#   40043061-1cf1-4bcc-97c5-83846e02616a.jpg  →  This is a leopard image  (conf: 87.1%)  [✓ MATCH with 'leopard']
#   401c4df8-5191-4e06-9115-7385f4d18f46.jpg  →  This is a leopard image  (conf: 83.9%)  [✓ MATCH with 'leopard']
#   4080a592-e468-47cc-9b97-99beff899d30.jpg  →  This is a leopard image  (conf: 69.4%)  [✓ MATCH with 'leopard']
#   425dc7da-e80b-4e34-b417-8084ac87ed66.jpg  →  This is a leopard image  (conf: 84.8%)  [✓ MATCH with 'leopard']
#   42995db8-406f-4a48-ba95-c1775bea3059.jpg  →  This is a leopard image  (conf: 66.6%)  [✓ MATCH with 'leopard']
#   440ec87c-deb1-488f-a49d-c16cc817d1a7.jpg  →  This is a leopard image  (conf: 92.7%)  [✓ MATCH with 'leopard']
#   469471d1-f402-4041-8910-b1508ff503b1.jpg  →  This is a leopard image  (conf: 92.3%)  [✓ MATCH with 'leopard']
#   46dca21c-65dc-4175-b9eb-2020f4d58210.jpg  →  This is a leopard image  (conf: 86.9%)  [✓ MATCH with 'leopard']
#   4725173f-98be-4073-afaf-bc3769b44d78.jpg  →  This is a leopard image  (conf: 89.7%)  [✓ MATCH with 'leopard']
#   47b11e17-8206-46b3-b980-4868f5065962.jpg  →  This is a leopard image  (conf: 85.4%)  [✓ MATCH with 'leopard']
#   4950dd1c-c02d-4c84-9f54-6192016a7a4e.jpg  →  This is a sheep image  (conf: 73.9%)  [✗ MISMATCH with 'leopard']
#   4a1dd933-f320-49bf-af43-0cf4d326618b.jpg  →  This is a leopard image  (conf: 92.2%)  [✓ MATCH with 'leopard']
#   4b4a8369-7a53-4e2e-8637-8bcd8c5e7ed8.jpg  →  This is a leopard image  (conf: 90.9%)  [✓ MATCH with 'leopard']
#   4b7f9ca4-2383-4063-b5fa-190258b14fc1.jpg  →  This is a leopard image  (conf: 88.8%)  [✓ MATCH with 'leopard']
#   4ca0f9a5-5125-4957-8a6d-6883db0b8389.jpg  →  This is a leopard image  (conf: 92.6%)  [✓ MATCH with 'leopard']
#   4faf915a-6e2c-4a7f-9f94-3edfefb47445.jpg  →  This is a leopard image  (conf: 88.3%)  [✓ MATCH with 'leopard']
#   4fd6b338-2139-47be-b965-480ac065cdc9.jpg  →  This is a leopard image  (conf: 90.8%)  [✓ MATCH with 'leopard']
#   5148aba8-261e-4a3b-a4fb-78abcf969084.jpg  →  This is a leopard image  (conf: 91.9%)  [✓ MATCH with 'leopard']
#   51c1fac8-a81c-4090-b7b4-7c1b1b9f3848.jpg  →  This is a leopard image  (conf: 91.3%)  [✓ MATCH with 'leopard']
#   563b2b3d-f12c-4ac6-b9e7-6996ca3a7db5.jpg  →  This is a leopard image  (conf: 87.8%)  [✓ MATCH with 'leopard']
#   56df17fd-ffc3-41cf-b946-20079f82c93b.jpg  →  This is a leopard image  (conf: 78.8%)  [✓ MATCH with 'leopard']
#   5870ed7e-ce36-410e-8837-a3f43682d17e.jpg  →  This is a leopard image  (conf: 83.8%)  [✓ MATCH with 'leopard']
#   58f18c78-2591-4b22-be3f-c7730237bb1b.jpg  →  This is a leopard image  (conf: 69.7%)  [✓ MATCH with 'leopard']
#   5a3bc495-57b2-4e5d-987d-5587d110a12d.jpg  →  This is a leopard image  (conf: 91.8%)  [✓ MATCH with 'leopard']
#   5b208f6e-2f60-4229-a859-c2b5b5d05872.jpg  →  This is a leopard image  (conf: 89.9%)  [✓ MATCH with 'leopard']
#   5fa5ad93-c78f-44b5-98b7-304f450033b3.jpg  →  This is a leopard image  (conf: 89.2%)  [✓ MATCH with 'leopard']
#   60195604-61e1-45d7-b55a-5d367baecc8b.jpg  →  This is a leopard image  (conf: 87.9%)  [✓ MATCH with 'leopard']
#   62078be6-4851-4c6e-99ee-e5818b999ee9.jpg  →  This is a leopard image  (conf: 83.8%)  [✓ MATCH with 'leopard']
#   62e6f608-ce07-4474-a817-e79dd4b7db09.jpg  →  This is a leopard image  (conf: 85.6%)  [✓ MATCH with 'leopard']
#   63ed4e73-34ab-40b1-a930-17cf2d9071fd.jpg  →  This is a leopard image  (conf: 79.7%)  [✓ MATCH with 'leopard']
#   667666c2-de94-41d7-ad56-66394dffb5e7.jpg  →  This is a leopard image  (conf: 82.1%)  [✓ MATCH with 'leopard']
#   684e3696-e79c-45f5-8ff4-492dda59a06b.jpg  →  This is a leopard image  (conf: 94.1%)  [✓ MATCH with 'leopard']
#   6abb75af-cfc4-4d90-b805-ce0cd2747ead.jpg  →  This is a leopard image  (conf: 84.2%)  [✓ MATCH with 'leopard']
#   6acedb99-8743-41fc-acb1-02f2d5499069.jpg  →  This is a leopard image  (conf: 88.6%)  [✓ MATCH with 'leopard']
#   6b978446-8ffe-42b1-98a0-3f6c97f346d7.jpg  →  This is a leopard image  (conf: 82.5%)  [✓ MATCH with 'leopard']
#   6cf6956d-2075-4b56-90a9-845cdb4a046d.jpg  →  This is a leopard image  (conf: 86.9%)  [✓ MATCH with 'leopard']
#   6d2b23bf-0eb1-4a69-b63d-33f2f591a856.jpg  →  This is a leopard image  (conf: 86.2%)  [✓ MATCH with 'leopard']
#   6e3497fd-d28a-46d0-9a2b-5d9398d31527.jpg  →  This is a leopard image  (conf: 86.2%)  [✓ MATCH with 'leopard']
#   71e71d6c-19ec-497d-b99d-0f1a2ff06a80.jpg  →  This is a leopard image  (conf: 72.3%)  [✓ MATCH with 'leopard']
#   720e4aef-32ae-49be-aae8-48a85322ccc0.jpg  →  This is a leopard image  (conf: 91.7%)  [✓ MATCH with 'leopard']
#   73186474-9e15-4adc-874f-c2d725c38b37.jpg  →  This is a leopard image  (conf: 85.8%)  [✓ MATCH with 'leopard']
#   73acdc83-cbd4-4518-b85a-5c66ff9da51b.jpg  →  This is a leopard image  (conf: 74.7%)  [✓ MATCH with 'leopard']
#   758ca2c7-8f5c-4fb1-862e-70a21b9c29d9.jpg  →  This is a leopard image  (conf: 89.2%)  [✓ MATCH with 'leopard']
#   7670d4a5-b373-4b87-9494-1cd06ede8497.jpg  →  This is a leopard image  (conf: 65.8%)  [✓ MATCH with 'leopard']
#   76c756e9-3f65-4b66-8632-5d921fb50671.jpg  →  This is a leopard image  (conf: 75.7%)  [✓ MATCH with 'leopard']
#   76efa6ab-6451-4356-b155-b993054bd9e1.jpg  →  This is a leopard image  (conf: 94.0%)  [✓ MATCH with 'leopard']
#   770a5890-3107-4110-b775-f0383cb34e9b.jpg  →  This is a leopard image  (conf: 85.3%)  [✓ MATCH with 'leopard']
#   7851374e-ddb5-4903-a635-656eca0f5a50.jpg  →  This is a leopard image  (conf: 91.5%)  [✓ MATCH with 'leopard']
#   7b913b49-f2ec-4d77-a72b-bcd332aadad6.jpg  →  This is a leopard image  (conf: 91.2%)  [✓ MATCH with 'leopard']
#   7dae5963-959c-4189-aba3-ceb0122e4d10.jpg  →  This is a leopard image  (conf: 52.3%)  [✓ MATCH with 'leopard']
#   7f1e505f-01ed-40ef-a350-cbc1d46bbe2a.jpg  →  This is a leopard image  (conf: 90.8%)  [✓ MATCH with 'leopard']
#   7f47b33f-7793-4f10-95aa-cc5f2f9aca25.jpg  →  This is a leopard image  (conf: 90.8%)  [✓ MATCH with 'leopard']
#   8145a22e-27f2-4fda-9cf3-8e754eecc094.jpg  →  This is a leopard image  (conf: 86.7%)  [✓ MATCH with 'leopard']
#   86872cb2-a00a-424c-9d66-801b06e9f34f.jpg  →  This is a leopard image  (conf: 91.8%)  [✓ MATCH with 'leopard']
#   88fb8ae5-20f3-47b7-9a29-f9cbd2d08b5c.jpg  →  This is a leopard image  (conf: 88.3%)  [✓ MATCH with 'leopard']
#   89b7195b-1033-4b00-9e08-93305fe741f3.jpg  →  This is a leopard image  (conf: 83.4%)  [✓ MATCH with 'leopard']
#   8c53b7b9-d01f-4f47-9c88-18efcff6c15e.jpg  →  This is a leopard image  (conf: 79.4%)  [✓ MATCH with 'leopard']
#   8e3d09e5-1694-40b7-9e67-82d49ae2d2cf.jpg  →  This is a leopard image  (conf: 85.0%)  [✓ MATCH with 'leopard']
#   8f23c1e7-bc84-4bf3-bd5d-65709d007bb5.jpg  →  This is a leopard image  (conf: 90.4%)  [✓ MATCH with 'leopard']
#   90a6cf43-6380-4606-9d52-3f617a4f79dd.jpg  →  This is a leopard image  (conf: 93.1%)  [✓ MATCH with 'leopard']
#   9364e9b9-6945-4625-a2d9-1ec0076d5aea.jpg  →  This is a leopard image  (conf: 69.3%)  [✓ MATCH with 'leopard']
#   947b99d8-cb6c-454f-b548-74827fe3a538.jpg  →  This is a leopard image  (conf: 34.6%)  [✓ MATCH with 'leopard']
#   96028c30-f6d1-4a13-af69-6d38a3e009cc.jpg  →  This is a leopard image  (conf: 88.3%)  [✓ MATCH with 'leopard']
#   978d0e50-3993-406e-b233-b582d128bd97.jpg  →  This is a leopard image  (conf: 81.9%)  [✓ MATCH with 'leopard']
#   990338c4-5dc7-49d9-8beb-ee272101e01f.jpg  →  This is a sheep image  (conf: 85.3%)  [✗ MISMATCH with 'leopard']
#   998f9db7-c33f-47e6-8f22-999c63c535d5.jpg  →  This is a fox image  (conf: 45.3%)  [✗ MISMATCH with 'leopard']
#   9be50da7-5248-4390-8486-218d659c0db2.jpg  →  This is a leopard image  (conf: 67.2%)  [✓ MATCH with 'leopard']
#   9e029225-b339-4cf4-9fa5-08130c5bb7e0.jpg  →  This is a leopard image  (conf: 89.6%)  [✓ MATCH with 'leopard']
#   a0c81e3e-dcff-4031-8cf6-1c76bc8e073c.jpg  →  This is a leopard image  (conf: 75.4%)  [✓ MATCH with 'leopard']
#   a5772cda-4931-4a08-9f84-62770146a784.jpg  →  This is a leopard image  (conf: 87.5%)  [✓ MATCH with 'leopard']
#   a5eacb66-04dd-4433-96f9-a4bf2d629e7e.jpg  →  This is a leopard image  (conf: 88.5%)  [✓ MATCH with 'leopard']
#   a7b8b123-7919-49fa-8e40-86977a2e5c23.jpg  →  This is a leopard image  (conf: 90.6%)  [✓ MATCH with 'leopard']
#   a987b38c-52b4-4d42-989c-7675fe7f073c.jpg  →  This is a leopard image  (conf: 90.0%)  [✓ MATCH with 'leopard']
#   ac4b1252-862e-482a-b473-2840f25acf5d.jpg  →  This is a leopard image  (conf: 87.2%)  [✓ MATCH with 'leopard']
#   ad14d9ae-c814-46c0-a393-17690fddc690.jpg  →  This is a leopard image  (conf: 89.2%)  [✓ MATCH with 'leopard']
#   b0a09177-a988-44ff-b1b5-05498b88bb7b.jpg  →  This is a leopard image  (conf: 79.2%)  [✓ MATCH with 'leopard']
#   b143dce0-6462-46d3-9dfb-6c6291f3268e.jpg  →  This is a leopard image  (conf: 84.7%)  [✓ MATCH with 'leopard']
#   b76d4807-c1b4-45b6-8bdf-da68e0f29730.jpg  →  This is a leopard image  (conf: 92.0%)  [✓ MATCH with 'leopard']
#   b887f473-b0ea-4709-bafe-0b6e1b5e24ef.jpg  →  This is a leopard image  (conf: 86.4%)  [✓ MATCH with 'leopard']
#   bbe07304-7124-47f1-9812-9410318dc0d9.jpg  →  This is a leopard image  (conf: 93.7%)  [✓ MATCH with 'leopard']
#   be7e05ce-13b9-4ad3-a5f0-7e411cfd3915.jpg  →  This is a leopard image  (conf: 91.2%)  [✓ MATCH with 'leopard']
#   bef9b616-914a-430f-8d4f-920d7d5bda74.jpg  →  This is a leopard image  (conf: 87.3%)  [✓ MATCH with 'leopard']
#   bf1cf8a4-fc97-445a-831f-5063edc247e6.jpg  →  This is a leopard image  (conf: 91.0%)  [✓ MATCH with 'leopard']
#   c4579cba-2605-4462-980a-91c34ed3599d.jpg  →  This is a leopard image  (conf: 87.2%)  [✓ MATCH with 'leopard']
#   c46609cd-b260-4447-ba99-2d5abc940aed.jpg  →  This is a leopard image  (conf: 88.8%)  [✓ MATCH with 'leopard']
#   c5632fc9-dbbf-4529-ab90-83255d69f392.jpg  →  This is a leopard image  (conf: 79.7%)  [✓ MATCH with 'leopard']
#   c67b49a0-28c1-4985-8ded-e1b056e186d9.jpg  →  This is a leopard image  (conf: 94.1%)  [✓ MATCH with 'leopard']
#   c7303e6a-e705-4741-9641-e64d08c90d90.jpg  →  This is a leopard image  (conf: 28.2%)  [✓ MATCH with 'leopard']
#   cb6245ae-5542-4515-8e3b-a5a07eaf45f7.jpg  →  This is a leopard image  (conf: 89.8%)  [✓ MATCH with 'leopard']
#   cbb4cc46-2f72-4239-bfed-7eefbd55d0db.jpg  →  This is a fox image  (conf: 49.3%)  [✗ MISMATCH with 'leopard']
#   ccaacccb-cc7b-4a10-b160-3c99b04a9d35.jpg  →  This is a leopard image  (conf: 91.4%)  [✓ MATCH with 'leopard']
#   ceb71aa3-73c2-45d3-a72b-70de7e6d640f.jpg  →  This is a leopard image  (conf: 82.2%)  [✓ MATCH with 'leopard']
#   cf75f0ec-f9f5-4ce5-9a4b-a3af79b2aac3.jpg  →  This is a leopard image  (conf: 86.9%)  [✓ MATCH with 'leopard']
#   d0af6588-24b2-48f6-bdf8-d501411fdef7.jpg  →  This is a leopard image  (conf: 88.9%)  [✓ MATCH with 'leopard']
#   d173ade5-10af-4604-8525-ca5aa09bcae0.jpg  →  This is a leopard image  (conf: 92.7%)  [✓ MATCH with 'leopard']
#   d53cbf93-8d9f-4738-96a5-fd44e416b2b2.jpg  →  This is a leopard image  (conf: 87.2%)  [✓ MATCH with 'leopard']
#   d54be21e-5cab-4b29-a9e6-487e67d9de04.jpg  →  This is a leopard image  (conf: 91.2%)  [✓ MATCH with 'leopard']
#   d5f7a74a-f2c4-4ae8-a167-1e42edafe8ce.jpg  →  This is a leopard image  (conf: 83.8%)  [✓ MATCH with 'leopard']
#   d6737ba4-f2dc-4519-b91d-0eb21641eca5.jpg  →  This is a leopard image  (conf: 81.6%)  [✓ MATCH with 'leopard']
#   dba23fd7-e031-4d81-af2a-88918661115e.jpg  →  This is a fox image  (conf: 44.8%)  [✗ MISMATCH with 'leopard']
#   ddbfe929-ef8b-4b2c-b322-9ecbd59242e2.jpg  →  This is a leopard image  (conf: 87.2%)  [✓ MATCH with 'leopard']
#   e0500fd1-8141-4ca2-a315-99b6e90f71ee.jpg  →  This is a leopard image  (conf: 87.3%)  [✓ MATCH with 'leopard']
#   e0b0e249-f63e-415f-9fcb-54bf9e15b3d8.jpg  →  This is a leopard image  (conf: 91.0%)  [✓ MATCH with 'leopard']
#   e2aed00a-acde-42ae-8952-4ddc5602b95a.jpg  →  This is a leopard image  (conf: 88.5%)  [✓ MATCH with 'leopard']
#   e414b85d-6922-44a1-a093-e19af3c74a95.jpg  →  This is a leopard image  (conf: 79.0%)  [✓ MATCH with 'leopard']
#   e8c3dbb3-07a9-43dc-8980-ce37d4e67797.jpg  →  This is a leopard image  (conf: 87.8%)  [✓ MATCH with 'leopard']
#   e91e7493-f303-409a-8958-ec236205a8b6.jpg  →  This is a leopard image  (conf: 90.1%)  [✓ MATCH with 'leopard']
#   e958b1f2-1a33-469f-a3e6-3b3774ddeb72.jpg  →  This is a leopard image  (conf: 88.2%)  [✓ MATCH with 'leopard']
#   eaf44755-2bfd-499c-9a7a-9ae4dae9818d.jpg  →  This is a leopard image  (conf: 59.3%)  [✓ MATCH with 'leopard']
#   eb3ecf91-52ca-4c40-9c58-a23e1881ddb1.jpg  →  This is a leopard image  (conf: 80.6%)  [✓ MATCH with 'leopard']
#   efbbb2e5-4337-402f-a7d9-ab180695f638.jpg  →  This is a leopard image  (conf: 91.6%)  [✓ MATCH with 'leopard']
#   f00c1b82-4e85-47c7-bce0-abb93fbd7bd3.jpg  →  This is a leopard image  (conf: 80.6%)  [✓ MATCH with 'leopard']
#   f1110548-289f-4526-9719-14b748a751a4.jpg  →  This is a sheep image  (conf: 75.4%)  [✗ MISMATCH with 'leopard']
#   f1c7d9b3-150f-44c1-b21f-300cce499581.jpg  →  This is a leopard image  (conf: 88.9%)  [✓ MATCH with 'leopard']
#   f1ccf636-bf22-4cb0-b520-6a19c7b2590b.jpg  →  This is a leopard image  (conf: 87.0%)  [✓ MATCH with 'leopard']
#   f24a8fc6-8089-4d83-8768-8ebe10472b47.jpg  →  This is a leopard image  (conf: 83.7%)  [✓ MATCH with 'leopard']
#   f7955f3d-b68d-41df-adb5-eebd26ac292a.jpg  →  This is a leopard image  (conf: 91.9%)  [✓ MATCH with 'leopard']
#   f94422c9-f516-4e70-ae55-5e4c519dae73.jpg  →  This is a leopard image  (conf: 87.7%)  [✓ MATCH with 'leopard']
#   f9a04bb3-76d5-450c-a191-c54333e6c772.jpg  →  This is a leopard image  (conf: 92.4%)  [✓ MATCH with 'leopard']
#   f9dffc2b-bd3d-46a4-bcc4-61dd02db1e1b.jpg  →  This is a leopard image  (conf: 42.5%)  [✓ MATCH with 'leopard']
#   f9f6e65d-9dc9-4536-a911-1058a6baba6d.jpg  →  no detection (conf≥25%) [GT: leopard]
#   fa503327-3848-4ee5-8b3b-45ec11a511b9.jpg  →  This is a leopard image  (conf: 87.3%)  [✓ MATCH with 'leopard']
#   fc7f0d1b-4d2f-4054-a083-e669e9e0f21e.jpg  →  This is a leopard image  (conf: 83.0%)  [✓ MATCH with 'leopard']
#   fe1ba187-5936-486b-839e-28f32259aa08.jpg  →  This is a leopard image  (conf: 89.3%)  [✓ MATCH with 'leopard']
#   ff549780-3882-4e03-8cfc-22b2cdc4c878.jpg  →  This is a leopard image  (conf: 80.3%)  [✓ MATCH with 'leopard']
#
# ── Summary ──────────────────────────────────────────────────
#   Target Folder  : leopard
#   Total images   : 166
#   Detected       : 165
#   No detection   : 1
#   Correct Match  : 157 / 166
#   Folder Accuracy: 94.58%
#   Breakdown      :
#     fox                  3 image(s)
#     leopard              157 image(s)
#     sheep                5 image(s)
# ──────────────────────────────────────────────────────────────

# %%
# !unzip 494-fox-labeled-image-dataset.zip
# Out:
# Archive:  494-fox-labeled-image-dataset.zip
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/10PSL8T23UZC.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/2AUNLDRG3BWP.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/2TR6JZF204SA.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/3O5MAZZVB9JC.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/3TMR10IVT67Y.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/444S9RVW0IZS.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/45HWY27DGR9Y.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/55BTPD5Z8DLM.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/55ELPUKUL7V7.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/5LF5WQPXC3LC.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/5O2JASKUJ8C9.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/5XVA9PDZZA1T.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/64FFCS6CV12O.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/68ONF8W1262H.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/6RXQRRXSF7IC.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/6W88HSXKJX6O.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/6X4VMGPF6HUX.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/7MXW71IBKICK.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/9YD5AHH9NSPA.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/A2ILOAHAAFS7.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/AEE14M3SZ041.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/C1ATLXAO5X7D.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/C7CMZF8X18MW.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/CE0XMSXW9G60.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/D0Z051F2G49V.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/DKTBE58BVXFR.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/DM6KZ6RFGC9H.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox/DS9LISWIBLMK.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/test/animal fox
jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/val/animal fox/W66KF89S3LGY.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/data/val/animal fox/XW5PFYWW3QKG.jpg
#   inflating: images.cv_8rk8h3aklzqjr2tcx76b7/readme.txt

# %%
# !python predict.py --folder fox
# Out:
# [INFO] Loading model from: /content/drive/MyDrive/yolo_backups/animal_detector_v8s_run-3/weights/best.pt
#
# [INFO] Found 349 image(s) in fox
#
#   File                                         Prediction
#   ----------------------------------------     -------------------------------------------------------
#   0E28A402D6C4.jpg                          →  This is a fox image  (conf: 79.6%)  [✓ MATCH with 'fox']
#   0LR38HR39B7O.jpg                          →  This is a fox image  (conf: 80.0%)  [✓ MATCH with 'fox']
#   0LR38HR39B7O_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   0U07Q7554CKO.jpg                          →  This is a fox image  (conf: 54.2%)  [✓ MATCH with 'fox']
#   0U07Q7554CKO_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   10E589LYMWS0.jpg                          →  This is a fox image  (conf: 77.7%)  [✓ MATCH with 'fox']
#   10PSL8T23UZC.jpg                          →  This is a fox image  (conf: 91.0%)  [✓ MATCH with 'fox']
#   12FG3W85AWC0.jpg                          →  This is a fox image  (conf: 88.8%)  [✓ MATCH with 'fox']
#   17IZFMGFRM3P.jpg                          →  This is a fox image  (conf: 91.3%)  [✓ MATCH with 'fox']
#   1C6XQGFIFLSD.jpg                          →  This is a fox image  (conf: 85.8%)  [✓ MATCH with 'fox']
#   1C6XQGFIFLSD_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   1EB0FWD7QUPB.jpg                          →  This is a fox image  (conf: 32.4%)  [✓ MATCH with 'fox']
#   1P5947EQOG1Q.jpg                          →  This is a fox image  (conf: 83.1%)  [✓ MATCH with 'fox']
#   1P5947EQOG1Q_aug.jpg                      →  This is a fox image  (conf: 38.7%)  [✓ MATCH with 'fox']
#   2AUNLDRG3BWP.jpg                          →  This is a fox image  (conf: 61.8%)  [✓ MATCH with 'fox']
#   2BWB37STRFS1.jpg                          →  This is a fox image  (conf: 85.2%)  [✓ MATCH with 'fox']
#   2BWB37STRFS1_aug.jpg                      →  This is a fox image  (conf: 68.9%)  [✓ MATCH with 'fox']
#   2KK6340G87XI.jpg                          →  This is a fox image  (conf: 84.7%)  [✓ MATCH with 'fox']
#   2M68R0KTQ9C4.jpg                          →  This is a fox image  (conf: 83.1%)  [✓ MATCH with 'fox']
#   2M68R0KTQ9C4_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   2RPKB44SXRO3.jpg                          →  This is a fox image  (conf: 85.9%)  [✓ MATCH with 'fox']
#   2TR6JZF204SA.jpg                          →  This is a fox image  (conf: 86.3%)  [✓ MATCH with 'fox']
#   2WA2OLVNXBZD.jpg                          →  This is a fox image  (conf: 90.2%)  [✓ MATCH with 'fox']
#   3IISYCWSQ6FM.jpg                          →  This is a fox image  (conf: 81.6%)  [✓ MATCH with 'fox']
#   3LIA0T8E2ZME.jpg                          →  This is a fox image  (conf: 79.8%)  [✓ MATCH with 'fox']
#   3MMXVPI2W2L3.jpg                          →  This is a sheep image  (conf: 28.1%)  [✗ MISMATCH with 'fox']
#   3MMXVPI2W2L3_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   3O5MAZZVB9JC.jpg                          →  This is a fox image  (conf: 74.4%)  [✓ MATCH with 'fox']
#   3TMR10IVT67Y.jpg                          →  This is a fox image  (conf: 94.5%)  [✓ MATCH with 'fox']
#   3XW1LNIU9XE4.jpg                          →  This is a fox image  (conf: 94.6%)  [✓ MATCH with 'fox']
#   43NJB3RJU07I.jpg                          →  This is a fox image  (conf: 46.8%)  [✓ MATCH with 'fox']
#   43ROS0JS6Q05.jpg                          →  This is a fox image  (conf: 70.0%)  [✓ MATCH with 'fox']
#   444S9RVW0IZS.jpg                          →  This is a fox image  (conf: 52.4%)  [✓ MATCH with 'fox']
#   45HWY27DGR9Y.jpg                          →  This is a fox image  (conf: 40.0%)  [✓ MATCH with 'fox']
#   47B8ZCBT4HNR.jpg                          →  This is a fox image  (conf: 93.9%)  [✓ MATCH with 'fox']
#   4EYOU7A8CHK4.jpg                          →  This is a fox image  (conf: 93.5%)  [✓ MATCH with 'fox']
#   4JFONNM3F9ZQ.jpg                          →  This is a fox image  (conf: 87.9%)  [✓ MATCH with 'fox']
#   4JFONNM3F9ZQ_aug.jpg                      →  This is a leopard image  (conf: 64.4%)  [✗ MISMATCH with 'fox']
#   4LOSW3TLHP0M.jpg                          →  This is a fox image  (conf: 81.9%)  [✓ MATCH with 'fox']
#   4LOSW3TLHP0M_aug.jpg                      →  This is a leopard image  (conf: 53.8%)  [✗ MISMATCH with 'fox']
#   4NMI4RYHQ8CB.jpg                          →  This is a fox image  (conf: 83.7%)  [✓ MATCH with 'fox']
#   4NMI4RYHQ8CB_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   4XMHPP680IWM.jpg                          →  This is a fox image  (conf: 73.4%)  [✓ MATCH with 'fox']
#   55BTPD5Z8DLM.jpg                          →  no detection (conf≥25%) [GT: fox]
#   55ELPUKUL7V7.jpg                          →  This is a fox image  (conf: 92.4%)  [✓ MATCH with 'fox']
#   57GQFMUZR5UN.jpg                          →  This is a fox image  (conf: 78.7%)  [✓ MATCH with 'fox']
#   5JMGEFUZWY2O.jpg                          →  no detection (conf≥25%) [GT: fox]
#   5LDG5LC4JLJT.jpg                          →  This is a fox image  (conf: 70.1%)  [✓ MATCH with 'fox']
#   5LDG5LC4JLJT_aug.jpg                      →  This is a fox image  (conf: 36.6%)  [✓ MATCH with 'fox']
#   5LF5WQPXC3LC.jpg                          →  This is a fox image  (conf: 85.4%)  [✓ MATCH with 'fox']
#   5O2JASKUJ8C9.jpg                          →  This is a fox image  (conf: 34.7%)  [✓ MATCH with 'fox']
#   5XVA9PDZZA1T.jpg                          →  This is a fox image  (conf: 46.3%)  [✓ MATCH with 'fox']
#   64FFCS6CV12O.jpg                          →  This is a fox image  (conf: 85.2%)  [✓ MATCH with 'fox']
#   68ONF8W1262H.jpg                          →  This is a fox image  (conf: 32.9%)  [✓ MATCH with 'fox']
#   6EX2HUENGTEW.jpg                          →  This is a fox image  (conf: 83.3%)  [✓ MATCH with 'fox']
#   6EX2HUENGTEW_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   6KT7UODFW5IS.jpg                          →  This is a fox image  (conf: 78.3%)  [✓ MATCH with 'fox']
#   6RXQRRXSF7IC.jpg                          →  This is a sheep image  (conf: 77.4%)  [✗ MISMATCH with 'fox']
#   6T5VC6CMN8VP.jpg                          →  This is a fox image  (conf: 91.6%)  [✓ MATCH with 'fox']
#   6W88HSXKJX6O.jpg                          →  This is a fox image  (conf: 76.1%)  [✓ MATCH with 'fox']
#   6X4VMGPF6HUX.jpg                          →  This is a sheep image  (conf: 27.5%)  [✗ MISMATCH with 'fox']
#   73DUHAHG48UN.jpg                          →  This is a fox image  (conf: 86.4%)  [✓ MATCH with 'fox']
#   7L00BJXBJZ84.jpg                          →  This is a fox image  (conf: 79.3%)  [✓ MATCH with 'fox']
#   7MGBWN4PWC7F.jpg                          →  This is a fox image  (conf: 91.9%)  [✓ MATCH with 'fox']
#   7MGBWN4PWC7F_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   7MXW71IBKICK.jpg                          →  This is a fox image  (conf: 93.8%)  [✓ MATCH with 'fox']
#   7O2TXJ6IL960.jpg                          →  This is a fox image  (conf: 89.3%)  [✓ MATCH with 'fox']
#   7Y4EL9YMTW1R.jpg                          →  This is a fox image  (conf: 38.2%)  [✓ MATCH with 'fox']
#   8693SF7NUJ5I.jpg                          →  This is a fox image  (conf: 78.0%)  [✓ MATCH with 'fox']
#   8JWY7WHMH263.jpg                          →  no detection (conf≥25%) [GT: fox]
#   8KCXP4R8XGAQ.jpg                          →  This is a fox image  (conf: 95.7%)  [✓ MATCH with 'fox']
#   8KCXP4R8XGAQ_aug.jpg                      →  This is a sheep image  (conf: 70.4%)  [✗ MISMATCH with 'fox']
#   8N769AM1XRT7.jpg                          →  This is a fox image  (conf: 85.0%)  [✓ MATCH with 'fox']
#   8PWKPRWWSI35.jpg                          →  This is a fox image  (conf: 89.7%)  [✓ MATCH with 'fox']
#   98407ZZIH1ZZ.jpg                          →  This is a sheep image  (conf: 48.0%)  [✗ MISMATCH with 'fox']
#   98407ZZIH1ZZ_aug.jpg                      →  This is a leopard image  (conf: 62.4%)  [✗ MISMATCH with 'fox']
#   98SHFPFNVBW7.jpg                          →  This is a fox image  (conf: 75.8%)  [✓ MATCH with 'fox']
#   98SHFPFNVBW7_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   9Y6ATUM66B2N.jpg                          →  This is a fox image  (conf: 85.2%)  [✓ MATCH with 'fox']
#   9Y6ATUM66B2N_aug.jpg                      →  This is a fox image  (conf: 76.6%)  [✓ MATCH with 'fox']
#   9YD5AHH9NSPA.jpg                          →  This is a fox image  (conf: 76.0%)  [✓ MATCH with 'fox']
#   A2ILOAHAAFS7.jpg                          →  This is a fox image  (conf: 75.0%)  [✓ MATCH with 'fox']
#   A3VCKNSP93NG.jpg                          →  This is a fox image  (conf: 68.2%)  [✓ MATCH with 'fox']
#   A3VCKNSP93NG_aug.jpg                      →  This is a leopard image  (conf: 31.4%)  [✗ MISMATCH with 'fox']
#   AAYGPPQZDJ98.jpg                          →  This is a fox image  (conf: 88.3%)  [✓ MATCH with 'fox']
#   AAYGPPQZDJ98_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   AEE14M3SZ041.jpg                          →  This is a fox image  (conf: 92.3%)  [✓ MATCH with 'fox']
#   ALH3QG8T6BIN.jpg                          →  This is a fox image  (conf: 79.4%)  [✓ MATCH with 'fox']
#   AS77RRSUVE0T.jpg                          →  This is a fox image  (conf: 83.1%)  [✓ MATCH with 'fox']
#   AWJ61CQJF0X7.jpg                          →  This is a fox image  (conf: 84.8%)  [✓ MATCH with 'fox']
#   B22V52B55E8F.jpg                          →  This is a fox image  (conf: 94.2%)  [✓ MATCH with 'fox']
#   B2VCE04XR3NE.jpg                          →  This is a fox image  (conf: 93.6%)  [✓ MATCH with 'fox']
#   B2VCE04XR3NE_aug.jpg                      →  This is a sheep image  (conf: 31.8%)  [✗ MISMATCH with 'fox']
#   B4SBVUTXL5CU.jpg                          →  This is a fox image  (conf: 78.7%)  [✓ MATCH with 'fox']
#   B5YPZDDHZMXV.jpg                          →  This is a fox image  (conf: 76.4%)  [✓ MATCH with 'fox']
#   BIF8VV593UWN.jpg                          →  This is a fox image  (conf: 69.4%)  [✓ MATCH with 'fox']
#   BROWG6P5ZV47.jpg                          →  This is a fox image  (conf: 83.6%)  [✓ MATCH with 'fox']
#   BROWG6P5ZV47_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   C1ATLXAO5X7D.jpg                          →  This is a fox image  (conf: 84.6%)  [✓ MATCH with 'fox']
#   C64RDFT8W41A.jpg                          →  This is a sheep image  (conf: 85.5%)  [✗ MISMATCH with 'fox']
#   C64RDFT8W41A_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   C7CMZF8X18MW.jpg                          →  This is a fox image  (conf: 91.3%)  [✓ MATCH with 'fox']
#   CE0XMSXW9G60.jpg                          →  This is a fox image  (conf: 25.3%)  [✓ MATCH with 'fox']
#   CMC94K1YSE7R.jpg                          →  This is a fox image  (conf: 90.8%)  [✓ MATCH with 'fox']
#   COQ81KFT8KJG.jpg                          →  This is a fox image  (conf: 78.7%)  [✓ MATCH with 'fox']
#   COQ81KFT8KJG_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   CRX0FSIDNGE6.jpg                          →  This is a fox image  (conf: 90.6%)  [✓ MATCH with 'fox']
#   CRX0FSIDNGE6_aug.jpg                      →  This is a leopard image  (conf: 27.9%)  [✗ MISMATCH with 'fox']
#   D0Y3FOC859CI.jpg                          →  This is a fox image  (conf: 66.3%)  [✓ MATCH with 'fox']
#   D0Y3FOC859CI_aug.jpg                      →  This is a leopard image  (conf: 49.2%)  [✗ MISMATCH with 'fox']
#   D0Z051F2G49V.jpg                          →  This is a fox image  (conf: 72.8%)  [✓ MATCH with 'fox']
#   DAJZ8M22E9VH.jpg                          →  This is a fox image  (conf: 82.6%)  [✓ MATCH with 'fox']
#   DAJZ8M22E9VH_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   DENS5SAZKYF6.jpg                          →  This is a fox image  (conf: 84.1%)  [✓ MATCH with 'fox']
#   DGGSOM6V6III.jpg                          →  This is a fox image  (conf: 86.8%)  [✓ MATCH with 'fox']
#   DGGSOM6V6III_aug.jpg                      →  This is a leopard image  (conf: 69.2%)  [✗ MISMATCH with 'fox']
#   DK6EE7ELDLUP.jpg                          →  This is a fox image  (conf: 87.4%)  [✓ MATCH with 'fox']
#   DKTBE58BVXFR.jpg                          →  This is a fox image  (conf: 91.7%)  [✓ MATCH with 'fox']
#   DL18BBYMPUBV.jpg                          →  This is a fox image  (conf: 68.8%)  [✓ MATCH with 'fox']
#   DL18BBYMPUBV_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   DM6KZ6RFGC9H.jpg                          →  This is a fox image  (conf: 80.5%)  [✓ MATCH with 'fox']
#   DS9LISWIBLMK.jpg                          →  This is a fox image  (conf: 85.4%)  [✓ MATCH with 'fox']
#   DSCX39XHNPWT.jpg                          →  This is a sheep image  (conf: 65.4%)  [✗ MISMATCH with 'fox']
#   DTJ137A8D0VT.jpg                          →  This is a fox image  (conf: 94.1%)  [✓ MATCH with 'fox']
#   DTJ137A8D0VT_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   DZEJVCR4P3K4.jpg                          →  This is a fox image  (conf: 93.7%)  [✓ MATCH with 'fox']
#   EBIN35O8SU83.jpg                          →  This is a fox image  (conf: 48.2%)  [✓ MATCH with 'fox']
#   EEDF7NAE54N7.jpg                          →  This is a fox image  (conf: 39.4%)  [✓ MATCH with 'fox']
#   EEDF7NAE54N7_aug.jpg                      →  This is a fox image  (conf: 42.7%)  [✓ MATCH with 'fox']
#   EGLP2FE95DL9.jpg                          →  This is a fox image  (conf: 49.8%)  [✓ MATCH with 'fox']
#   EGU97N8LMP9C.jpg                          →  This is a fox image  (conf: 80.7%)  [✓ MATCH with 'fox']
#   EMKA23ZBDQJO.jpg                          →  This is a fox image  (conf: 76.7%)  [✓ MATCH with 'fox']
#   EOI38DG6FMZW.jpg                          →  This is a fox image  (conf: 84.9%)  [✓ MATCH with 'fox']
#   EOI38DG6FMZW_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   EPAOXUNNNA98.jpg                          →  This is a fox image  (conf: 89.6%)  [✓ MATCH with 'fox']
#   ESS3XOH9133Q.jpg                          →  This is a sheep image  (conf: 63.3%)  [✗ MISMATCH with 'fox']
#   ET5C8E2SVEZA.jpg                          →  This is a fox image  (conf: 81.3%)  [✓ MATCH with 'fox']
#   ET5C8E2SVEZA_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   F9DJEMJTF0T5.jpg                          →  This is a fox image  (conf: 81.2%)  [✓ MATCH with 'fox']
#   FAE9DYU4GTY4.jpg                          →  This is a fox image  (conf: 79.5%)  [✓ MATCH with 'fox']
#   FAE9DYU4GTY4_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   FEC2TBTV6EQ0.jpg                          →  This is a fox image  (conf: 77.5%)  [✓ MATCH with 'fox']
#   FEC2TBTV6EQ0_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   FPOATWJUZW6P.jpg                          →  This is a fox image  (conf: 75.1%)  [✓ MATCH with 'fox']
#   FPOATWJUZW6P_aug.jpg                      →  This is a leopard image  (conf: 77.3%)  [✗ MISMATCH with 'fox']
#   FY08PRVLLYQT.jpg                          →  This is a fox image  (conf: 90.0%)  [✓ MATCH with 'fox']
#   FY08PRVLLYQT_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   G3A7UIYBW2BD.jpg                          →  This is a fox image  (conf: 82.4%)  [✓ MATCH with 'fox']
#   G3A7UIYBW2BD_aug.jpg                      →  This is a fox image  (conf: 63.9%)  [✓ MATCH with 'fox']
#   G5CK2TFWHEEH.jpg                          →  This is a fox image  (conf: 79.7%)  [✓ MATCH with 'fox']
#   G5TG02LBG5QK.jpg                          →  This is a fox image  (conf: 81.7%)  [✓ MATCH with 'fox']
#   G5TG02LBG5QK_aug.jpg                      →  This is a leopard image  (conf: 26.6%)  [✗ MISMATCH with 'fox']
#   G7CHS2HY4M6D.jpg                          →  This is a fox image  (conf: 69.4%)  [✓ MATCH with 'fox']
#   G7IKT3QW6A75.jpg                          →  This is a fox image  (conf: 89.5%)  [✓ MATCH with 'fox']
#   G8ZFDPIQZULZ.jpg                          →  This is a fox image  (conf: 57.7%)  [✓ MATCH with 'fox']
#   G8ZFDPIQZULZ_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   G9OE4ZNWBM2F.jpg                          →  This is a fox image  (conf: 68.0%)  [✓ MATCH with 'fox']
#   G9OE4ZNWBM2F_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   GAQWX2MMJA3P.jpg                          →  This is a fox image  (conf: 89.8%)  [✓ MATCH with 'fox']
#   GAQWX2MMJA3P_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   GAUQ1LSID01N.jpg                          →  This is a sheep image  (conf: 45.6%)  [✗ MISMATCH with 'fox']
#   GAUQ1LSID01N_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   GB1TFWZ3VGW1.jpg                          →  This is a fox image  (conf: 47.5%)  [✓ MATCH with 'fox']
#   GB1TFWZ3VGW1_aug.jpg                      →  This is a leopard image  (conf: 67.9%)  [✗ MISMATCH with 'fox']
#   GLVBCGSXYA3R.jpg                          →  This is a fox image  (conf: 93.4%)  [✓ MATCH with 'fox']
#   GMMMSJI3L3E7.jpg                          →  This is a fox image  (conf: 73.5%)  [✓ MATCH with 'fox']
#   GPYF7TODR1T7.jpg                          →  This is a fox image  (conf: 76.0%)  [✓ MATCH with 'fox']
#   GYXLTD0UP3GB.jpg                          →  This is a fox image  (conf: 92.7%)  [✓ MATCH with 'fox']
#   H1KBDHMSQFXJ.jpg                          →  This is a fox image  (conf: 92.2%)  [✓ MATCH with 'fox']
#   H2Z6IFCN2ZZ7.jpg                          →  This is a fox image  (conf: 68.7%)  [✓ MATCH with 'fox']
#   H5CKXJ6BUTGH.jpg                          →  This is a fox image  (conf: 87.3%)  [✓ MATCH with 'fox']
#   H6MGYKKFX6PD.jpg                          →  This is a fox image  (conf: 71.5%)  [✓ MATCH with 'fox']
#   H6XYIQKYFSWX.jpg                          →  This is a fox image  (conf: 86.4%)  [✓ MATCH with 'fox']
#   H7WE6MNZ8ERI.jpg                          →  This is a fox image  (conf: 89.4%)  [✓ MATCH with 'fox']
#   H7WE6MNZ8ERI_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   HFYHYW3KM85O.jpg                          →  This is a fox image  (conf: 51.4%)  [✓ MATCH with 'fox']
#   HKHN5AA2L5U1.jpg                          →  This is a fox image  (conf: 87.8%)  [✓ MATCH with 'fox']
#   HQBQAPLIJB0M.jpg                          →  This is a fox image  (conf: 85.0%)  [✓ MATCH with 'fox']
#   I7DCLJP2K48Y.jpg                          →  This is a fox image  (conf: 91.8%)  [✓ MATCH with 'fox']
#   I7DCLJP2K48Y_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   IAUAR6NPZH4E.jpg                          →  This is a fox image  (conf: 80.9%)  [✓ MATCH with 'fox']
#   ICN3U0LX5B8X.jpg                          →  no detection (conf≥25%) [GT: fox]
#   JBZ6T4N1SJ96.jpg                          →  This is a fox image  (conf: 76.2%)  [✓ MATCH with 'fox']
#   JBZ6T4N1SJ96_aug.jpg                      →  This is a fox image  (conf: 79.3%)  [✓ MATCH with 'fox']
#   JC4UM5OI9RAE.jpg                          →  This is a fox image  (conf: 75.5%)  [✓ MATCH with 'fox']
#   JDBGKBCE0EXK.jpg                          →  This is a fox image  (conf: 85.4%)  [✓ MATCH with 'fox']
#   JDBGKBCE0EXK_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   JGDS9MH5GNUK.jpg                          →  This is a fox image  (conf: 69.7%)  [✓ MATCH with 'fox']
#   JGDS9MH5GNUK_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   JGSDIW4CJQPU.jpg                          →  This is a fox image  (conf: 89.1%)  [✓ MATCH with 'fox']
#   JGSDIW4CJQPU_aug.jpg                      →  This is a fox image  (conf: 31.3%)  [✓ MATCH with 'fox']
#   JJTCCGHBZYM2.jpg                          →  This is a fox image  (conf: 79.8%)  [✓ MATCH with 'fox']
#   JW7XTQ4DUS7I.jpg                          →  This is a fox image  (conf: 83.4%)  [✓ MATCH with 'fox']
#   JW7XTQ4DUS7I_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   KG35YOUNYUZJ.jpg                          →  This is a fox image  (conf: 74.8%)  [✓ MATCH with 'fox']
#   KGM5YUFGY3IE.jpg                          →  This is a fox image  (conf: 80.4%)  [✓ MATCH with 'fox']
#   KGM5YUFGY3IE_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   KLKBA47EYSVV.jpg                          →  This is a fox image  (conf: 93.0%)  [✓ MATCH with 'fox']
#   KNQGAU0P4UEI.jpg                          →  This is a fox image  (conf: 86.8%)  [✓ MATCH with 'fox']
#   KUPKXFMZLWZB.jpg                          →  This is a fox image  (conf: 77.0%)  [✓ MATCH with 'fox']
#   KUPKXFMZLWZB_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   L97EQ8N2D2RK.jpg                          →  This is a fox image  (conf: 91.9%)  [✓ MATCH with 'fox']
#   LD0LQ6P3SLCU.jpg                          →  This is a sheep image  (conf: 88.5%)  [✗ MISMATCH with 'fox']
#   LD0LQ6P3SLCU_aug.jpg                      →  This is a fox image  (conf: 50.3%)  [✓ MATCH with 'fox']
#   LDSJU6WBD3QC.jpg                          →  This is a fox image  (conf: 73.2%)  [✓ MATCH with 'fox']
#   LDSJU6WBD3QC_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   LGU2KR4QAPEO.jpg                          →  This is a fox image  (conf: 87.7%)  [✓ MATCH with 'fox']
#   LGU2KR4QAPEO_aug.jpg                      →  This is a fox image  (conf: 32.3%)  [✓ MATCH with 'fox']
#   LS0NM9V6WOPD.jpg                          →  This is a fox image  (conf: 86.1%)  [✓ MATCH with 'fox']
#   LS0NM9V6WOPD_aug.jpg                      →  This is a leopard image  (conf: 52.3%)  [✗ MISMATCH with 'fox']
#   LT2HUNQRFEO8.jpg                          →  This is a fox image  (conf: 83.2%)  [✓ MATCH with 'fox']
#   M0XCN9O1TEPQ.jpg                          →  no detection (conf≥25%) [GT: fox]
#   M3XJG6JOX948.jpg                          →  This is a fox image  (conf: 87.8%)  [✓ MATCH with 'fox']
#   M3XJG6JOX948_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   M9RLVJHJ5R9Z.jpg                          →  This is a fox image  (conf: 88.1%)  [✓ MATCH with 'fox']
#   MAT2SHI2AQJR.jpg                          →  This is a fox image  (conf: 95.1%)  [✓ MATCH with 'fox']
#   MDI56RGZHAKP.jpg                          →  This is a fox image  (conf: 84.1%)  [✓ MATCH with 'fox']
#   MJU2VZ0LDUXV.jpg                          →  This is a fox image  (conf: 78.4%)  [✓ MATCH with 'fox']
#   MJU2VZ0LDUXV_aug.jpg                      →  This is a fox image  (conf: 35.3%)  [✓ MATCH with 'fox']
#   MORK8F79S5HA.jpg                          →  This is a fox image  (conf: 80.7%)  [✓ MATCH with 'fox']
#   MR48K6KK9FEZ.jpg                          →  This is a fox image  (conf: 87.9%)  [✓ MATCH with 'fox']
#   MSO66CTZ3PYU.jpg                          →  This is a fox image  (conf: 89.4%)  [✓ MATCH with 'fox']
#   MZENGZ3B07R5.jpg                          →  This is a fox image  (conf: 84.8%)  [✓ MATCH with 'fox']
#   N21KL005ZSA8.jpg                          →  This is a fox image  (conf: 79.1%)  [✓ MATCH with 'fox']
#   N6YRK9N9MNZB.jpg                          →  This is a fox image  (conf: 75.9%)  [✓ MATCH with 'fox']
#   NEKTZATDAHQW.jpg                          →  This is a fox image  (conf: 91.0%)  [✓ MATCH with 'fox']
#   NGFIJ141NQX9.jpg                          →  This is a fox image  (conf: 77.5%)  [✓ MATCH with 'fox']
#   NHAJS4J5OX09.jpg                          →  This is a fox image  (conf: 83.0%)  [✓ MATCH with 'fox']
#   NHAJS4J5OX09_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   NTYTYGFSYLDV.jpg                          →  This is a fox image  (conf: 70.7%)  [✓ MATCH with 'fox']
#   NZAAH42XJ19U.jpg                          →  This is a fox image  (conf: 84.4%)  [✓ MATCH with 'fox']
#   NZAAH42XJ19U_aug.jpg                      →  This is a sheep image  (conf: 33.1%)  [✗ MISMATCH with 'fox']
#   O70P523HF08E.jpg                          →  This is a fox image  (conf: 81.2%)  [✓ MATCH with 'fox']
#   OAJ7025VPFX4.jpg                          →  This is a fox image  (conf: 88.2%)  [✓ MATCH with 'fox']
#   OAJ7025VPFX4_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   OJTS8F2XHWLW.jpg                          →  This is a fox image  (conf: 64.5%)  [✓ MATCH with 'fox']
#   OJTS8F2XHWLW_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   OT9XI0AG1AW9.jpg                          →  This is a fox image  (conf: 83.9%)  [✓ MATCH with 'fox']
#   OVIVS7TO7MI9.jpg                          →  This is a fox image  (conf: 67.7%)  [✓ MATCH with 'fox']
#   OVIVS7TO7MI9_aug.jpg                      →  This is a leopard image  (conf: 59.3%)  [✗ MISMATCH with 'fox']
#   P3L7QLTRGQAT.jpg                          →  This is a fox image  (conf: 79.0%)  [✓ MATCH with 'fox']
#   P6QFATI82WQJ.jpg                          →  This is a fox image  (conf: 72.4%)  [✓ MATCH with 'fox']
#   P74FXWBVLVDT.jpg                          →  This is a fox image  (conf: 75.7%)  [✓ MATCH with 'fox']
#   P74FXWBVLVDT_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   P7PQ7WFL09FE.jpg                          →  This is a fox image  (conf: 90.8%)  [✓ MATCH with 'fox']
#   P7PQ7WFL09FE_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   P9NW7Z8M9YBE.jpg                          →  This is a fox image  (conf: 88.7%)  [✓ MATCH with 'fox']
#   P9NW7Z8M9YBE_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   PA7K63J0T19K.jpg                          →  This is a fox image  (conf: 80.3%)  [✓ MATCH with 'fox']
#   PAC9R5WNNLHW.jpg                          →  This is a fox image  (conf: 90.7%)  [✓ MATCH with 'fox']
#   PCJ5K9GCHTQK.jpg                          →  This is a fox image  (conf: 87.5%)  [✓ MATCH with 'fox']
#   PCJ5K9GCHTQK_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   PLT04T7TOC41.jpg                          →  This is a fox image  (conf: 73.4%)  [✓ MATCH with 'fox']
#   PNHD08CFL74K.jpg                          →  This is a fox image  (conf: 85.2%)  [✓ MATCH with 'fox']
#   PRO8E8UMZGB1.jpg                          →  This is a fox image  (conf: 89.5%)  [✓ MATCH with 'fox']
#   PT24NZQC7M7A.jpg                          →  This is a fox image  (conf: 86.8%)  [✓ MATCH with 'fox']
#   PT24NZQC7M7A_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   Q81DJDPOB4DZ.jpg                          →  This is a fox image  (conf: 92.4%)  [✓ MATCH with 'fox']
#   Q81DJDPOB4DZ_aug.jpg                      →  This is a fox image  (conf: 33.0%)  [✓ MATCH with 'fox']
#   QMKA34AR0ZJU.jpg                          →  This is a fox image  (conf: 77.5%)  [✓ MATCH with 'fox']
#   QWINSTGS7K24.jpg                          →  This is a fox image  (conf: 82.3%)  [✓ MATCH with 'fox']
#   R4FNXJB159M6.jpg                          →  This is a fox image  (conf: 66.8%)  [✓ MATCH with 'fox']
#   RCW3LYPPKEJF.jpg                          →  This is a fox image  (conf: 80.8%)  [✓ MATCH with 'fox']
#   RCW3LYPPKEJF_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   RDJKD74CPJVM.jpg                          →  This is a fox image  (conf: 86.9%)  [✓ MATCH with 'fox']
#   RMOJ21NERMTE.jpg                          →  This is a sheep image  (conf: 57.1%)  [✗ MISMATCH with 'fox']
#   RMOJ21NERMTE_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   RR79BM4TOXHY.jpg                          →  This is a fox image  (conf: 86.4%)  [✓ MATCH with 'fox']
#   RYQV7GVLUN56.jpg                          →  This is a fox image  (conf: 82.9%)  [✓ MATCH with 'fox']
#   RYQV7GVLUN56_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   S3CUGA7NJ02T.jpg                          →  This is a fox image  (conf: 73.8%)  [✓ MATCH with 'fox']
#   S7YENZY0WBUQ.jpg                          →  This is a fox image  (conf: 31.0%)  [✓ MATCH with 'fox']
#   SL6TGR9GAOHI.jpg                          →  This is a fox image  (conf: 82.4%)  [✓ MATCH with 'fox']
#   SL6TGR9GAOHI_aug.jpg                      →  This is a leopard image  (conf: 30.6%)  [✗ MISMATCH with 'fox']
#   SQ5LLW8EO2GU.jpg                          →  This is a fox image  (conf: 71.6%)  [✓ MATCH with 'fox']
#   SQ5LLW8EO2GU_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   SQUAUR93919P.jpg                          →  This is a fox image  (conf: 85.6%)  [✓ MATCH with 'fox']
#   SQUAUR93919P_aug.jpg                      →  This is a leopard image  (conf: 70.7%)  [✗ MISMATCH with 'fox']
#   SUHKTH7YAJV2.jpg                          →  This is a fox image  (conf: 81.7%)  [✓ MATCH with 'fox']
#   SUHKTH7YAJV2_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   SVGE5VF1Q7BK.jpg                          →  no detection (conf≥25%) [GT: fox]
#   SVGE5VF1Q7BK_aug.jpg                      →  This is a fox image  (conf: 68.9%)  [✓ MATCH with 'fox']
#   SYG5VH3744M4.jpg                          →  This is a fox image  (conf: 71.0%)  [✓ MATCH with 'fox']
#   SYG5VH3744M4_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   SYOQVBXE0G5V.jpg                          →  This is a fox image  (conf: 82.2%)  [✓ MATCH with 'fox']
#   SYWFEB73HMZ2.jpg                          →  This is a fox image  (conf: 82.9%)  [✓ MATCH with 'fox']
#   SYWFEB73HMZ2_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   TEMEIJEM3OWH.jpg                          →  This is a fox image  (conf: 71.4%)  [✓ MATCH with 'fox']
#   TPED7J3CL334.jpg                          →  This is a fox image  (conf: 43.4%)  [✓ MATCH with 'fox']
#   TYH7TMKGG6U2.jpg                          →  This is a fox image  (conf: 42.5%)  [✓ MATCH with 'fox']
#   TYH7TMKGG6U2_aug.jpg                      →  This is a leopard image  (conf: 37.7%)  [✗ MISMATCH with 'fox']
#   U8TV88YXM5E4.jpg                          →  This is a fox image  (conf: 52.4%)  [✓ MATCH with 'fox']
#   U8TV88YXM5E4_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   ULLF4V7SC8FH.jpg                          →  This is a fox image  (conf: 55.5%)  [✓ MATCH with 'fox']
#   UOBST7T8HINL.jpg                          →  This is a fox image  (conf: 82.7%)  [✓ MATCH with 'fox']
#   UOBST7T8HINL_aug.jpg                      →  This is a leopard image  (conf: 33.1%)  [✗ MISMATCH with 'fox']
#   URM4TH7Q9O0F.jpg                          →  This is a fox image  (conf: 72.9%)  [✓ MATCH with 'fox']
#   UU8F8R9E2AUX.jpg                          →  This is a fox image  (conf: 91.8%)  [✓ MATCH with 'fox']
#   UVERPEJOBF8C.jpg                          →  This is a fox image  (conf: 83.7%)  [✓ MATCH with 'fox']
#   UXNJA7U07DSX.jpg                          →  This is a fox image  (conf: 72.2%)  [✓ MATCH with 'fox']
#   UXNJA7U07DSX_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   V4LH9R3F6PEQ.jpg                          →  This is a fox image  (conf: 71.0%)  [✓ MATCH with 'fox']
#   VB66L1RLDPKA.jpg                          →  This is a fox image  (conf: 72.9%)  [✓ MATCH with 'fox']
#   VC5T5FP8EA89.jpg                          →  This is a fox image  (conf: 82.0%)  [✓ MATCH with 'fox']
#   VC5T5FP8EA89_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   VC7AHWWYC1VO.jpg                          →  This is a fox image  (conf: 72.6%)  [✓ MATCH with 'fox']
#   VC7AHWWYC1VO_aug.jpg                      →  This is a leopard image  (conf: 38.1%)  [✗ MISMATCH with 'fox']
#   VWEDE1NAGPO6.jpg                          →  This is a fox image  (conf: 82.7%)  [✓ MATCH with 'fox']
#   VWEDE1NAGPO6_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   VXBAXNX1INTM.jpg                          →  This is a fox image  (conf: 49.0%)  [✓ MATCH with 'fox']
#   VXBAXNX1INTM_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   W0IY9WYEHAKM.jpg                          →  This is a fox image  (conf: 87.9%)  [✓ MATCH with 'fox']
#   W66KF89S3LGY.jpg                          →  This is a fox image  (conf: 85.7%)  [✓ MATCH with 'fox']
#   WPTYHN5TLQI0.jpg                          →  This is a fox image  (conf: 78.6%)  [✓ MATCH with 'fox']
#   WUOK8JC56OTC.jpg                          →  This is a fox image  (conf: 82.6%)  [✓ MATCH with 'fox']
#   WXZBJHKEB9PU.jpg                          →  This is a fox image  (conf: 90.3%)  [✓ MATCH with 'fox']
#   X24I998WIUJS.jpg                          →  This is a fox image  (conf: 42.6%)  [✓ MATCH with 'fox']
#   X24I998WIUJS_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   XAZ514HSCIQJ.jpg                          →  This is a fox image  (conf: 83.6%)  [✓ MATCH with 'fox']
#   XFRFUYQBB1RW.jpg                          →  This is a fox image  (conf: 79.8%)  [✓ MATCH with 'fox']
#   XHO82LI31UUT.jpg                          →  This is a fox image  (conf: 85.4%)  [✓ MATCH with 'fox']
#   XN25W421G52J.jpg                          →  This is a fox image  (conf: 80.3%)  [✓ MATCH with 'fox']
#   XOWUEJBZ907M.jpg                          →  This is a fox image  (conf: 77.3%)  [✓ MATCH with 'fox']
#   XS46GTRTB46D.jpg                          →  This is a fox image  (conf: 85.4%)  [✓ MATCH with 'fox']
#   XS46GTRTB46D_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   XSIWTRQEBTZS.jpg                          →  This is a fox image  (conf: 86.9%)  [✓ MATCH with 'fox']
#   XSIWTRQEBTZS_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   XW5PFYWW3QKG.jpg                          →  This is a fox image  (conf: 89.9%)  [✓ MATCH with 'fox']
#   XWF8U6E4XKC4.jpg                          →  This is a fox image  (conf: 84.2%)  [✓ MATCH with 'fox']
#   Y0IOSJ0KQ17P.jpg                          →  This is a fox image  (conf: 82.9%)  [✓ MATCH with 'fox']
#   Y0IOSJ0KQ17P_aug.jpg                      →  This is a fox image  (conf: 36.6%)  [✓ MATCH with 'fox']
#   Y0MJRQXJ4G8L.jpg                          →  This is a fox image  (conf: 81.6%)  [✓ MATCH with 'fox']
#   Y0MJRQXJ4G8L_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   YCVFM6YD9BPL.jpg                          →  This is a fox image  (conf: 80.9%)  [✓ MATCH with 'fox']
#   YCVFM6YD9BPL_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   YFBD123H3I65.jpg                          →  This is a fox image  (conf: 81.3%)  [✓ MATCH with 'fox']
#   YXEG3F7JPOLM.jpg                          →  This is a sheep image  (conf: 55.6%)  [✗ MISMATCH with 'fox']
#   YXEG3F7JPOLM_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   YZHPKZ723Y09.jpg                          →  This is a sheep image  (conf: 65.2%)  [✗ MISMATCH with 'fox']
#   YZHPKZ723Y09_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   Z6AZ8T7C2J6O.jpg                          →  This is a fox image  (conf: 89.3%)  [✓ MATCH with 'fox']
#   Z6AZ8T7C2J6O_aug.jpg                      →  This is a fox image  (conf: 29.6%)  [✓ MATCH with 'fox']
#   ZA9T3FVYIDHH.jpg                          →  This is a fox image  (conf: 90.2%)  [✓ MATCH with 'fox']
#   ZA9T3FVYIDHH_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   ZP0XI9N0HSCK.jpg                          →  This is a fox image  (conf: 84.8%)  [✓ MATCH with 'fox']
#   ZP0XI9N0HSCK_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#   ZTJVZFY7HOFL.jpg                          →  This is a sheep image  (conf: 77.9%)  [✗ MISMATCH with 'fox']
#   ZYWI3JGT0N46.jpg                          →  This is a sheep image  (conf: 75.2%)  [✗ MISMATCH with 'fox']
#   ZYWI3JGT0N46_aug.jpg                      →  no detection (conf≥25%) [GT: fox]
#
# ── Summary ──────────────────────────────────────────────────
#   Target Folder  : fox
#   Total images   : 349
#   Detected       : 279
#   No detection   : 70
#   Correct Match  : 245 / 349
#   Folder Accuracy: 70.20%
#   Breakdown      :
#     fox                  245 image(s)
#     leopard              17 image(s)
#     sheep                17 image(s)
# ──────────────────────────────────────────────────────────────
